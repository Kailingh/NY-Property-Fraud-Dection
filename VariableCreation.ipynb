# %%
import pandas as pd
import numpy as np
import scipy.stats as sps 
import matplotlib.pyplot as plt 
import seaborn as sns
import sklearn as skl
from sklearn import preprocessing 
# %matplotlib inline

# %%
# %%time
data = pd.read_csv('NY property data_FILLED.csv')
# Out:
# CPU times: user 10.5 s, sys: 1.38 s, total: 11.9 s
# Wall time: 11.8 s

# %%
# S1
data["lotarea"] = data["LTFRONT"] * data["LTDEPTH"]

# %%
# S2
data["bldarea"] = data["BLDFRONT"] * data["BLDDEPTH"]

# %%
data["bldarea"].describe()
# Out:
# count    1.070994e+06
# mean     3.948917e+03
# std      9.884419e+04
# min      1.000000e+00
# 25%      7.200000e+02
# 50%      1.050000e+03
# 75%      2.100000e+03
# max      7.115198e+07
# Name: bldarea, dtype: float64

# %%
data["bldarea"].isnull().sum()
# Out:
# 0

# %%
# S3
data["bldvol"] = data["bldarea"] * data["STORIES"]

# %%
data["bldvol"].isnull().sum()
# Out:
# 0

# %%
# r1 = V1 / S1
data["FULLVAL_r1"] = data["FULLVAL"] / data["lotarea"]

# %%
# r2 = V2 / S2
data["FULLVAL_r2"] = data["FULLVAL"] / data["bldarea"]

# %%
# r3 = V3 / S3
data["FULLVAL_r3"] = data["FULLVAL"] / data["bldvol"]

# %%
# r4 = V4 / S4
data["AVLAND_r4"] = data["AVLAND"] / data["lotarea"]

# %%
# r5 = V5 / S5
data["AVLAND_r5"] = data["AVLAND"] / data["bldarea"]

# %%
# r6 = V6 / S6
data["AVLAND_r6"] = data["AVLAND"] / data["bldvol"]

# %%
# r7 = V7 / S7
data["AVTOT_r7"] = data["AVTOT"] / data["lotarea"]

# %%
# r8 = V8 / S8
data["AVTOT_r8"] = data["AVTOT"] / data["bldarea"]

# %%
# r9 = V9 / S9
data["AVTOT_r9"] = data["AVTOT"] / data["bldvol"]

# %%
data.drop(['Unnamed: 0',
 'Unnamed: 0.1',
 'Unnamed: 0.1.1',
 'RECORD',
 'LOT',
 'EASEMENT',
 'OWNER',
 'EXT',
 'EXLAND',
 'EXTOT',
 'EXCD1',
 'STADDR',
 'EXMPTCL',
 'AVLAND2',
 'AVTOT2',
 'EXLAND2',
 'EXTOT2',
 'EXCD2',
 'PERIOD',
 'YEAR',
 'VALTYPE'],axis=1, inplace=True)
data.head()
# Out:
#          BBLE  B  BLOCK BLDGCL TAXCLASS  LTFRONT  LTDEPTH  STORIES  \
# 0  1000010101  1      1     P7        4    500.0   1046.0     35.0
# 1  1000010201  1      1     Z9        4     27.0    355.0     35.0
# 2  1000020001  1      2     Y7        4    709.0    564.0      3.0
# 3  1000020023  1      2     T2        4    793.0    551.0      2.0
# 4  1000030001  1      3     Q1        4    323.0   1260.0      1.0
#
#        FULLVAL       AVLAND      ...          bldvol    FULLVAL_r1  \
# 0   21400000.0    4225500.0      ...       4251660.0     40.917782
# 1  193800000.0   14310000.0      ...       4251660.0  20219.092332
# 2  104686000.0   39008700.0      ...       1199628.0    261.796157
# 3   39200000.0   15255000.0      ...         93670.0     89.714219
# 4  272300000.0  121050000.0      ...          5073.0    669.074647
#
#      FULLVAL_r2    FULLVAL_r3    AVLAND_r4     AVLAND_r5     AVLAND_r6  \
# 0    176.166486      5.033328     8.079350     34.784649      0.993847
# 1   1595.376865     45.582196  1492.957746    117.801047      3.365744
# 2    261.796157     87.265386    97.551991     97.551991     32.517330
# 3    836.980890    418.490445    34.913021    325.717946    162.858973
# 4  53676.325646  53676.325646   297.434763  23861.620343  23861.620343
#
#       AVTOT_r7      AVTOT_r8      AVTOT_r9
# 0    18.413002     79.274919      2.264998
# 1  9098.591549    717.919589     20.511988
# 2   117.808271    117.808271     39.269424
# 3    40.371399    376.641401    188.320700
# 4   301.083591  24154.346541  24154.346541
#
# [5 rows x 34 columns]

# %% [markdown]
# # Var 37-45

# %%
data["r1_all"] = data["FULLVAL_r1"] / data["FULLVAL_r1"].mean()

# %%
data["r2_all"] = data["FULLVAL_r2"] / data["FULLVAL_r2"].mean()

# %%
data["r3_all"] = data["FULLVAL_r3"] / data["FULLVAL_r3"].mean()

# %%
data["r4_all"] = data["AVLAND_r4"] / data["AVLAND_r4"].mean()

# %%
data["r5_all"] = data["AVLAND_r5"] / data["AVLAND_r5"].mean()

# %%
data["r6_all"] = data["AVLAND_r6"] / data["AVLAND_r6"].mean()

# %%
data["r7_all"] = data["AVTOT_r7"] / data["AVTOT_r7"].mean()

# %%
data["r8_all"] = data["AVTOT_r8"] / data["AVTOT_r8"].mean()

# %%
data["r9_all"] = data["AVTOT_r9"] / data["AVTOT_r9"].mean()

# %%
data.head()
# Out:
#          BBLE  B  BLOCK BLDGCL TAXCLASS  LTFRONT  LTDEPTH  STORIES  \
# 0  1000010101  1      1     P7        4    500.0   1046.0     35.0
# 1  1000010201  1      1     Z9        4     27.0    355.0     35.0
# 2  1000020001  1      2     Y7        4    709.0    564.0      3.0
# 3  1000020023  1      2     T2        4    793.0    551.0      2.0
# 4  1000030001  1      3     Q1        4    323.0   1260.0      1.0
#
#        FULLVAL       AVLAND     ...          AVTOT_r9     r1_all     r2_all  \
# 0   21400000.0    4225500.0     ...          2.264998   0.115466   0.291491
# 1  193800000.0   14310000.0     ...         20.511988  57.056097   2.639763
# 2  104686000.0   39008700.0     ...         39.269424   0.738761   0.433176
# 3   39200000.0   15255000.0     ...        188.320700   0.253164   1.384896
# 4  272300000.0  121050000.0     ...      24154.346541   1.888056  88.814598
#
#        r3_all      r4_all      r5_all       r6_all      r7_all      r8_all  \
# 0    0.018031    0.650247    0.818948     0.048907    0.540661    1.049730
# 1    0.163294  120.157017    2.773434     0.165627  267.161795    9.506437
# 2    0.312620    7.851231    2.296703     1.600162    3.459202    1.559975
# 3    1.499202    2.809888    7.668499     8.014211    1.185425    4.987352
# 4  192.290339   23.938302  561.783017  1174.218807    8.840713  319.843317
#
#        r9_all
# 0    0.073146
# 1    0.662419
# 2    1.268177
# 3    6.081676
# 4  780.046571
#
# [5 rows x 43 columns]

# %% [markdown]
# # Var1 (r1_byzip5)

# %%
# r1 group by zip5
data_group_zip5 = data.groupby("ZIP")["FULLVAL_r1"].mean()
data_group_zip5 = pd.DataFrame({'ZIP5':data_group_zip5.index, 'r1_mean_groupby_zip5':data_group_zip5})
data_group_zip5
# Out:
#             ZIP5  r1_mean_groupby_zip5
# ZIP
# 10001.0  10001.0            584.549965
# 10002.0  10002.0            370.458745
# 10003.0  10003.0            607.263009
# 10004.0  10004.0            314.981754
# 10005.0  10005.0            108.870462
# 10006.0  10006.0            241.503724
# 10007.0  10007.0            251.383183
# 10009.0  10009.0            506.382087
# 10010.0  10010.0            348.755359
# 10011.0  10011.0            459.986785
# 10012.0  10012.0            671.035073
# 10013.0  10013.0            325.165698
# 10014.0  10014.0            908.115540
# 10016.0  10016.0            266.923791
# 10017.0  10017.0            349.572423
# 10018.0  10018.0            842.688751
# 10019.0  10019.0            183.565627
# 10020.0  10020.0            765.919535
# 10021.0  10021.0            572.168285
# 10022.0  10022.0            461.528444
# 10023.0  10023.0            207.420540
# 10024.0  10024.0            515.582845
# 10025.0  10025.0            328.020995
# 10026.0  10026.0            158.599974
# 10027.0  10027.0            361.143929
# 10028.0  10028.0            585.725441
# 10029.0  10029.0            284.695676
# 10030.0  10030.0            308.759885
# 10031.0  10031.0            283.859042
# 10032.0  10032.0            256.955648
# ...          ...                   ...
# 11412.0  11412.0            114.168903
# 11413.0  11413.0            114.291983
# 11414.0  11414.0            127.703863
# 11415.0  11415.0            174.941901
# 11416.0  11416.0            184.773022
# 11417.0  11417.0            160.880653
# 11418.0  11418.0            161.011515
# 11419.0  11419.0            175.269449
# 11420.0  11420.0            147.335007
# 11421.0  11421.0            198.388180
# 11422.0  11422.0            105.155587
# 11423.0  11423.0            129.988331
# 11426.0  11426.0            131.067476
# 11427.0  11427.0            141.845424
# 11428.0  11428.0            127.789613
# 11429.0  11429.0            112.500413
# 11430.0  11430.0            142.904951
# 11432.0  11432.0            363.873341
# 11433.0  11433.0            135.439886
# 11434.0  11434.0            119.063423
# 11435.0  11435.0            156.964879
# 11436.0  11436.0            130.061930
# 11691.0  11691.0            110.316985
# 11692.0  11692.0            198.602251
# 11693.0  11693.0            158.294879
# 11694.0  11694.0            165.003140
# 11695.0  11695.0            161.918025
# 11696.0  11696.0             30.178792
# 11697.0  11697.0            178.085070
# 33803.0  33803.0             55.423729
#
# [196 rows x 2 columns]

# %%
## create r1_mean_groupby_zip5 column
data1 = data.merge(data_group_zip5, on =['ZIP'], how = 'left')
data = data1
data
# Out:
#                BBLE  B  BLOCK BLDGCL TAXCLASS  LTFRONT  LTDEPTH  STORIES  \
# 0        1000010101  1      1     P7        4    500.0   1046.0     35.0
# 1        1000010201  1      1     Z9        4     27.0    355.0     35.0
# 2        1000020001  1      2     Y7        4    709.0    564.0      3.0
# 3        1000020023  1      2     T2        4    793.0    551.0      2.0
# 4        1000030001  1      3     Q1        4    323.0   1260.0      1.0
# 5        1000030002  1      3     Q1        4    496.0     76.0     35.0
# 6        1000030003  1      3     Q1        4    180.0    370.0      1.0
# 7        1000030010  1      3     Z9        4    362.0    177.0      3.0
# 8        1000041001  1      4     R5        4    422.0    355.0     50.0
# 9        1000041002  1      4     R5        4    422.0    355.0     50.0
# 10       1000041003  1      4     R5        4    422.0    355.0     50.0
# 11       1000041004  1      4     R5        4    422.0    355.0     50.0
# 12       1000041005  1      4     R5        4    422.0    355.0     50.0
# 13       1000041006  1      4     R5        4    422.0    355.0     50.0
# 14       1000041007  1      4     R5        4    422.0    355.0     50.0
# 15       1000041008  1      4     R5        4    422.0    355.0     50.0
# 16       1000041009  1      4     R5        4    422.0    355.0     50.0
# 17       1000041010  1      4     R5        4    422.0    355.0     50.0
# 18       1000041011  1      4     R5        4    422.0    355.0     50.0
# 19       1000041012  1      4     R5        4    422.0    355.0     50.0
# 20       1000041013  1      4     R5        4    422.0    355.0     50.0
# 21       1000041014  1      4     R5        4    422.0    355.0     50.0
# 22       1000041015  1      4     R5        4    422.0    355.0     50.0
# 23       1000041016  1      4     R5        4    422.0    355.0     50.0
# 24       1000041017  1      4     R5        4    422.0    355.0     50.0
# 25       1000041018  1      4     R5        4    422.0    355.0     50.0
# 26       1000041019  1      4     R5        4    422.0    355.0     50.0
# 27       1000041020  1      4     R5        4    422.0    355.0     50.0
# 28       1000041021  1      4     R5        4    422.0    355.0     50.0
# 29       1000041022  1      4     R5        4    422.0    355.0     50.0
# ...             ... ..    ...    ...      ...      ...      ...      ...
# 1070964  5080500001  5   8050     B2        1     56.0    117.0      2.0
# 1070965  5080500004  5   8050     A1        1     65.0    112.0      2.0
# 1070966  5080500007  5   8050     A1        1     59.0    213.0      3.0
# 1070967  5080500010  5   8050     A2        1     53.0    214.0      2.0
# 1070968  5080500013  5   8050     A2        1     67.0    214.0      2.0
# 1070969  5080500017  5   8050     A2        1     47.0    213.0      2.0
# 1070970  5080500019  5   8050     A1        1     60.0    190.0      2.0
# 1070971  5080500022  5   8050     A1        1     60.0    167.0      2.0
# 1070972  5080500025  5   8050     A1        1     60.0    147.0      2.0
# 1070973  5080500028  5   8050     A1        1     60.0    129.0      2.0
# 1070974  5080500031  5   8050     A1        1     60.0    107.0      2.0
# 1070975  5080500034  5   8050     A1        1     60.0    164.0      2.0
# 1070976  5080500037  5   8050     A3        1    141.0     87.0      2.0
# 1070977  5080500050  5   8050     A1        1     60.0     98.0      2.0
# 1070978  5080500053  5   8050     A1        1     58.0    116.0      2.0
# 1070979  5080500055  5   8050     V0       1B      2.0    119.0      2.0
# 1070980  5080500056  5   8050     B3        1     40.0    130.0      2.0
# 1070981  5080500058  5   8050     A1        1     40.0    145.0      2.0
# 1070982  5080500060  5   8050     A1        1     40.0    160.0      2.0
# 1070983  5080500062  5   8050     A1        1     60.0    180.0      2.0
# 1070984  5080500065  5   8050     A1        1     60.0    127.0      2.0
# 1070985  5080500068  5   8050     A1        1     75.0    127.0      2.0
# 1070986  5080500072  5   8050     A1        1     75.0    116.0      2.0
# 1070987  5080500076  5   8050     A1        1     33.0    116.0      2.0
# 1070988  5080500078  5   8050     A3        1    103.0     85.0      2.0
# 1070989  5080500083  5   8050     A1        1     60.0    120.0      2.0
# 1070990  5080500086  5   8050     A1        1     62.0    228.0      2.0
# 1070991  5080500089  5   8050     A1        1     53.0    273.0      2.0
# 1070992  5080500092  5   8050     A1        1     52.0    136.0      2.0
# 1070993  5080500094  5   8050     A1        1     50.0     80.0      2.0
#
#              FULLVAL       AVLAND          ...              r2_all  \
# 0         21400000.0    4225500.0          ...            0.291491
# 1        193800000.0   14310000.0          ...            2.639763
# 2        104686000.0   39008700.0          ...            0.433176
# 3         39200000.0   15255000.0          ...            1.384896
# 4        272300000.0  121050000.0          ...           88.814598
# 5         10600000.0    4770000.0          ...            0.144383
# 6          8489997.0    3820499.0          ...           46.209953
# 7         28100000.0   11070000.0          ...            5.535799
# 8          3944762.0     636093.0          ...            0.053732
# 9          5700930.0     919276.0          ...            0.077653
# 10        10600000.0     967500.0          ...            0.144383
# 11         1011928.0     163174.0          ...            0.013784
# 12         2318026.0     373783.0          ...            0.031574
# 13         2191531.0     353383.0          ...            0.029851
# 14         7730673.0    1246572.0          ...            0.105300
# 15         7524757.0    1213369.0          ...            0.102495
# 16         7524757.0    1213369.0          ...            0.102495
# 17         7524757.0    1213369.0          ...            0.102495
# 18         7524757.0    1213369.0          ...            0.102495
# 19         7524757.0    1213369.0          ...            0.102495
# 20         7524757.0    1213369.0          ...            0.102495
# 21         7524757.0    1213369.0          ...            0.102495
# 22         7521818.0    1212893.0          ...            0.102455
# 23         7424741.0    1197240.0          ...            0.101133
# 24         7424741.0    1197240.0          ...            0.101133
# 25         7665959.0    1236136.0          ...            0.104419
# 26         7665959.0    1236136.0          ...            0.104419
# 27         7665959.0    1236136.0          ...            0.104419
# 28         7665959.0    1236136.0          ...            0.104419
# 29         7648310.0    1233292.0          ...            0.104178
# ...              ...          ...          ...                 ...
# 1070964     553000.0      14032.0          ...            0.904162
# 1070965     576000.0      13793.0          ...            3.241729
# 1070966     534000.0      15160.0          ...            1.039499
# 1070967     518000.0       9338.0          ...            3.061070
# 1070968     637000.0      16452.0          ...            1.171112
# 1070969     490000.0      15889.0          ...            0.883192
# 1070970     472000.0      15187.0          ...            1.267835
# 1070971    1067000.0      26599.0          ...            2.052899
# 1070972     436000.0      13396.0          ...            0.990961
# 1070973     366000.0      14105.0          ...            1.294008
# 1070974     414000.0      16200.0          ...            0.951414
# 1070975     427000.0      15681.0          ...            1.308385
# 1070976     700000.0      26040.0          ...            1.645231
# 1070977     605000.0      14317.0          ...            1.480847
# 1070978     531000.0      16577.0          ...            0.896541
# 1070979       3720.0        108.0          ...            0.003240
# 1070980     414000.0      11911.0          ...            1.386676
# 1070981     436000.0      12888.0          ...            1.460364
# 1070982     673000.0      12692.0          ...            2.254186
# 1070983     488000.0      13815.0          ...            0.978740
# 1070984     463000.0      14557.0          ...            0.712646
# 1070985     498000.0      15916.0          ...            1.131878
# 1070986     669000.0      22800.0          ...            0.922458
# 1070987     397000.0      12104.0          ...            1.052707
# 1070988     569000.0       6379.0          ...            0.431083
# 1070989     438000.0      14536.0          ...            0.929140
# 1070990     544000.0       9303.0          ...            1.081875
# 1070991     480000.0      14790.0          ...            1.034145
# 1070992     543000.0      12388.0          ...            1.337002
# 1070993     473000.0      14061.0          ...            1.087002
#
#              r3_all      r4_all      r5_all       r6_all      r7_all  \
# 0          0.018031    0.650247    0.818948     0.048907    0.540661
# 1          0.163294  120.157017    2.773434     0.165627  267.161795
# 2          0.312620    7.851231    2.296703     1.600162    3.459202
# 3          1.499202    2.809888    7.668499     8.014211    1.185425
# 4        192.290339   23.938302  561.783017  1174.218807    8.840713
# 5          0.008931   10.184149    0.924478     0.055209    3.715552
# 6        100.048052    4.616868  295.879708   618.437203    1.684403
# 7          3.995142   13.904885   31.030496    21.619611    5.794783
# 8          0.002327    0.341729    0.123282     0.005154    0.347931
# 9          0.003362    0.493863    0.178166     0.007448    0.502826
# 10         0.006252    0.519771    0.187512     0.007839    0.934927
# 11         0.000597    0.087662    0.031625     0.001322    0.089253
# 12         0.001367    0.200808    0.072443     0.003028    0.204452
# 13         0.001293    0.189848    0.068489     0.002863    0.193295
# 14         0.004560    0.669697    0.241599     0.010100    0.681851
# 15         0.004438    0.651859    0.235164     0.009831    0.663689
# 16         0.004438    0.651859    0.235164     0.009831    0.663689
# 17         0.004438    0.651859    0.235164     0.009831    0.663689
# 18         0.004438    0.651859    0.235164     0.009831    0.663689
# 19         0.004438    0.651859    0.235164     0.009831    0.663689
# 20         0.004438    0.651859    0.235164     0.009831    0.663689
# 21         0.004438    0.651859    0.235164     0.009831    0.663689
# 22         0.004436    0.651603    0.235072     0.009827    0.663429
# 23         0.004379    0.643194    0.232038     0.009700    0.654867
# 24         0.004379    0.643194    0.232038     0.009700    0.654867
# 25         0.004521    0.664090    0.239577     0.010015    0.676143
# 26         0.004521    0.664090    0.239577     0.010015    0.676143
# 27         0.004521    0.664090    0.239577     0.010015    0.676143
# 28         0.004521    0.664090    0.239577     0.010015    0.676143
# 29         0.004511    0.662562    0.239025     0.009992    0.674586
# ...             ...         ...         ...          ...         ...
# 1070964    0.978790    0.172364    0.326443     0.341160    0.112182
# 1070965    3.509295    0.152486    1.104537     1.154331    0.095087
# 1070966    0.750198    0.097089    0.419903     0.292555    0.057492
# 1070967    3.313725    0.066262    0.785171     0.820569    0.038649
# 1070968    1.267773    0.092349    0.430373     0.449775    0.055032
# 1070969    0.956088    0.127738    0.407495     0.425866    0.076629
# 1070970    1.372480    0.107218    0.580444     0.606611    0.059177
# 1070971    2.222341    0.213648    0.728175     0.761002    0.150944
# 1070972    1.072753    0.122239    0.433224     0.452755    0.070198
# 1070973    1.400812    0.146667    0.709571     0.741560    0.074466
# 1070974    1.029941    0.203087    0.529726     0.553607    0.113610
# 1070975    1.416377    0.128257    0.683673     0.714495    0.066825
# 1070976    1.781025    0.170846    0.870837     0.910096    0.100534
# 1070977    1.603073    0.195964    0.498625     0.521104    0.129891
# 1070978    0.970539    0.198299    0.398243     0.416197    0.120053
# 1070979    0.003507    0.036521    0.001338     0.001399    0.013324
# 1070980    1.501129    0.184351    0.567662     0.593254    0.109626
# 1070981    1.580899    0.178838    0.614225     0.641915    0.116115
# 1070982    2.440241    0.159607    0.604884     0.632153    0.108258
# 1070983    1.059523    0.102951    0.394244     0.412018    0.061507
# 1070984    0.771467    0.153751    0.318810     0.333183    0.090809
# 1070985    1.225301    0.134484    0.514720     0.537925    0.080114
# 1070986    0.998595    0.210920    0.447324     0.467490    0.135475
# 1070987    1.139595    0.254483    0.456681     0.477269    0.156856
# 1070988    0.466664    0.058641    0.068765     0.071865    0.101441
# 1070989    1.005829    0.162485    0.438752     0.458532    0.095112
# 1070990    1.171171    0.052966    0.263250     0.275118    0.031010
# 1070991    1.119502    0.082268    0.453394     0.473834    0.046625
# 1070992    1.447356    0.140981    0.434011     0.453577    0.095650
# 1070993    1.176721    0.282916    0.459782     0.480510    0.164389
#
#              r8_all      r9_all     ZIP5  r1_mean_groupby_zip5
# 0          1.049730    0.073146  10004.0            314.981754
# 1          9.506437    0.662419  10004.0            314.981754
# 2          1.559975    1.268177  10004.0            314.981754
# 3          4.987352    6.081676  10004.0            314.981754
# 4        319.843317  780.046571  10004.0            314.981754
# 5          0.519960    0.036231  10004.0            314.981754
# 6        166.413477  405.855790  10004.0            314.981754
# 7         19.935780   16.206724  10004.0            314.981754
# 8          0.193502    0.009438  10004.0            314.981754
# 9          0.279647    0.013640  10004.0            314.981754
# 10         0.519960    0.025362  10004.0            314.981754
# 11         0.049638    0.002421  10004.0            314.981754
# 12         0.113706    0.005546  10004.0            314.981754
# 13         0.107501    0.005244  10004.0            314.981754
# 14         0.379211    0.018497  10004.0            314.981754
# 15         0.369111    0.018004  10004.0            314.981754
# 16         0.369111    0.018004  10004.0            314.981754
# 17         0.369111    0.018004  10004.0            314.981754
# 18         0.369111    0.018004  10004.0            314.981754
# 19         0.369111    0.018004  10004.0            314.981754
# 20         0.369111    0.018004  10004.0            314.981754
# 21         0.369111    0.018004  10004.0            314.981754
# 22         0.368966    0.017997  10004.0            314.981754
# 23         0.364204    0.017765  10004.0            314.981754
# 24         0.364204    0.017765  10004.0            314.981754
# 25         0.376037    0.018342  10004.0            314.981754
# 26         0.376037    0.018342  10004.0            314.981754
# 27         0.376037    0.018342  10004.0            314.981754
# 28         0.376037    0.018342  10004.0            314.981754
# 29         0.375171    0.018300  10004.0            314.981754
# ...             ...         ...      ...                   ...
# 1070964    0.327534    0.399402  10307.0            332.988057
# 1070965    1.061809    1.294791  10307.0            332.988057
# 1070966    0.383322    0.311621  10307.0            332.988057
# 1070967    0.706016    0.860930  10307.0            332.988057
# 1070968    0.395366    0.482117  10307.0            332.988057
# 1070969    0.376853    0.459542  10307.0            332.988057
# 1070970    0.493875    0.602241  10307.0            332.988057
# 1070971    0.793098    0.967119  10307.0            332.988057
# 1070972    0.383535    0.467690  10307.0            332.988057
# 1070973    0.555385    0.677248  10307.0            332.988057
# 1070974    0.456837    0.557076  10307.0            332.988057
# 1070975    0.549136    0.669627  10307.0            332.988057
# 1070976    0.789985    0.963323  10307.0            332.988057
# 1070977    0.509510    0.621306  10307.0            332.988057
# 1070978    0.371685    0.453240  10307.0            332.988057
# 1070979    0.000753    0.000918  10307.0            332.988057
# 1070980    0.520391    0.634576  10307.0            332.988057
# 1070981    0.614798    0.749697  10307.0            332.988057
# 1070982    0.632490    0.771270  10307.0            332.988057
# 1070983    0.363110    0.442784  10307.0            332.988057
# 1070984    0.290282    0.353975  10307.0            332.988057
# 1070985    0.472698    0.576417  10307.0            332.988057
# 1070986    0.442933    0.540121  10307.0            332.988057
# 1070987    0.433940    0.529155  10307.0            332.988057
# 1070988    0.183382    0.223620  10307.0            332.988057
# 1070989    0.395925    0.482799  10307.0            332.988057
# 1070990    0.237602    0.289736  10307.0            332.988057
# 1070991    0.396129    0.483047  10307.0            332.988057
# 1070992    0.453940    0.553544  10307.0            332.988057
# 1070993    0.411852    0.502220  10307.0            332.988057
#
# [1070994 rows x 45 columns]

# %%
### Var1
data["r1_byzip5"] = data["FULLVAL_r1"] / data["r1_mean_groupby_zip5"]

# %% [markdown]
# # Var 2 (r1_byzip3)

# %%
### covert ZIP to string in order to split to zip3
data['ZIP'] = data['ZIP'].astype(str)
type(data['ZIP'][0])
# Out:
# str

# %%
## split zip5 to zip3
data["ZIP3"] =  data["ZIP"].str.slice(start=0, stop=3)
data["ZIP3"].head()
# Out:
# 0    100
# 1    100
# 2    100
# 3    100
# 4    100
# Name: ZIP3, dtype: object

# %%
# r1 group by zip3
data_group_zip3 = data.groupby("ZIP3")["FULLVAL_r1"].mean()
data_group_zip3 = pd.DataFrame({'ZIP3_1':data_group_zip3.index, 'r1_mean_groupby_zip3':data_group_zip3})
data_group_zip3.head()
# Out:
#      ZIP3_1  r1_mean_groupby_zip3
# ZIP3
# 100     100            380.454314
# 101     101            360.092973
# 102     102             40.411633
# 103     103            157.661571
# 104     104            141.051173

# %%
## create r1_mean_groupby_zip3 column
data1 = data.merge(data_group_zip3, on =['ZIP3'], how = 'left')
data = data1
data.head()
# Out:
#          BBLE  B  BLOCK BLDGCL TAXCLASS  LTFRONT  LTDEPTH  STORIES  \
# 0  1000010101  1      1     P7        4    500.0   1046.0     35.0
# 1  1000010201  1      1     Z9        4     27.0    355.0     35.0
# 2  1000020001  1      2     Y7        4    709.0    564.0      3.0
# 3  1000020023  1      2     T2        4    793.0    551.0      2.0
# 4  1000030001  1      3     Q1        4    323.0   1260.0      1.0
#
#        FULLVAL       AVLAND          ...                r6_all      r7_all  \
# 0   21400000.0    4225500.0          ...              0.048907    0.540661
# 1  193800000.0   14310000.0          ...              0.165627  267.161795
# 2  104686000.0   39008700.0          ...              1.600162    3.459202
# 3   39200000.0   15255000.0          ...              8.014211    1.185425
# 4  272300000.0  121050000.0          ...           1174.218807    8.840713
#
#        r8_all      r9_all     ZIP5  r1_mean_groupby_zip5  r1_byzip5  ZIP3  \
# 0    1.049730    0.073146  10004.0            314.981754   0.129905   100
# 1    9.506437    0.662419  10004.0            314.981754  64.191313   100
# 2    1.559975    1.268177  10004.0            314.981754   0.831147   100
# 3    4.987352    6.081676  10004.0            314.981754   0.284824   100
# 4  319.843317  780.046571  10004.0            314.981754   2.124170   100
#
#    ZIP3_1  r1_mean_groupby_zip3
# 0     100            380.454314
# 1     100            380.454314
# 2     100            380.454314
# 3     100            380.454314
# 4     100            380.454314
#
# [5 rows x 49 columns]

# %%
### Var2
data["r1_byzip3"] = data["FULLVAL_r1"] / data["r1_mean_groupby_zip3"]

# %% [markdown]
# # Var 3 (r1_by taxclass)

# %%
# r1 group by taxclass
data_group_taxclass = data.groupby("TAXCLASS")["FULLVAL_r1"].mean()
data_group_taxclass = pd.DataFrame({'TAXCLASS_1':data_group_taxclass.index, 'r1_mean_groupby_taxclass':data_group_taxclass})
data_group_taxclass
# Out:
#          TAXCLASS_1  r1_mean_groupby_taxclass
# TAXCLASS
# 1                 1                230.166460
# 1A               1A               6727.819698
# 1B               1B                182.299750
# 1C               1C                305.429066
# 1D               1D                103.687211
# 2                 2                 85.772960
# 2A               2A                410.973799
# 2B               2B                549.709131
# 2C               2C                302.032990
# 3                 3               1104.782255
# 4                 4                268.124564

# %%
#merge
data1 = data.merge(data_group_taxclass, on =['TAXCLASS'], how = 'left')

data= data1
data.head()
# Out:
#          BBLE  B  BLOCK BLDGCL TAXCLASS  LTFRONT  LTDEPTH  STORIES  \
# 0  1000010101  1      1     P7        4    500.0   1046.0     35.0
# 1  1000010201  1      1     Z9        4     27.0    355.0     35.0
# 2  1000020001  1      2     Y7        4    709.0    564.0      3.0
# 3  1000020023  1      2     T2        4    793.0    551.0      2.0
# 4  1000030001  1      3     Q1        4    323.0   1260.0      1.0
#
#        FULLVAL       AVLAND            ...                 r9_all     ZIP5  \
# 0   21400000.0    4225500.0            ...               0.073146  10004.0
# 1  193800000.0   14310000.0            ...               0.662419  10004.0
# 2  104686000.0   39008700.0            ...               1.268177  10004.0
# 3   39200000.0   15255000.0            ...               6.081676  10004.0
# 4  272300000.0  121050000.0            ...             780.046571  10004.0
#
#    r1_mean_groupby_zip5  r1_byzip5 ZIP3  ZIP3_1  r1_mean_groupby_zip3  \
# 0            314.981754   0.129905  100     100            380.454314
# 1            314.981754  64.191313  100     100            380.454314
# 2            314.981754   0.831147  100     100            380.454314
# 3            314.981754   0.284824  100     100            380.454314
# 4            314.981754   2.124170  100     100            380.454314
#
#    r1_byzip3  TAXCLASS_1  r1_mean_groupby_taxclass
# 0   0.107550           4                268.124564
# 1  53.144600           4                268.124564
# 2   0.688115           4                268.124564
# 3   0.235808           4                268.124564
# 4   1.758620           4                268.124564
#
# [5 rows x 52 columns]

# %%
### Var3
data["r1_bytaxclass"] = data["FULLVAL_r1"] / data["r1_mean_groupby_taxclass"]
data.head()
# Out:
#          BBLE  B  BLOCK BLDGCL TAXCLASS  LTFRONT  LTDEPTH  STORIES  \
# 0  1000010101  1      1     P7        4    500.0   1046.0     35.0
# 1  1000010201  1      1     Z9        4     27.0    355.0     35.0
# 2  1000020001  1      2     Y7        4    709.0    564.0      3.0
# 3  1000020023  1      2     T2        4    793.0    551.0      2.0
# 4  1000030001  1      3     Q1        4    323.0   1260.0      1.0
#
#        FULLVAL       AVLAND      ...           ZIP5 r1_mean_groupby_zip5  \
# 0   21400000.0    4225500.0      ...        10004.0           314.981754
# 1  193800000.0   14310000.0      ...        10004.0           314.981754
# 2  104686000.0   39008700.0      ...        10004.0           314.981754
# 3   39200000.0   15255000.0      ...        10004.0           314.981754
# 4  272300000.0  121050000.0      ...        10004.0           314.981754
#
#    r1_byzip5  ZIP3 ZIP3_1  r1_mean_groupby_zip3  r1_byzip3  TAXCLASS_1  \
# 0   0.129905   100    100            380.454314   0.107550           4
# 1  64.191313   100    100            380.454314  53.144600           4
# 2   0.831147   100    100            380.454314   0.688115           4
# 3   0.284824   100    100            380.454314   0.235808           4
# 4   2.124170   100    100            380.454314   1.758620           4
#
#    r1_mean_groupby_taxclass  r1_bytaxclass
# 0                268.124564       0.152607
# 1                268.124564      75.409325
# 2                268.124564       0.976398
# 3                268.124564       0.334599
# 4                268.124564       2.495387
#
# [5 rows x 53 columns]

# %% [markdown]
# # Var4 (r1 group by borough)

# %%
# r1 group by B
data_group_b = data.groupby("B")["FULLVAL_r1"].mean()
data_group_b = pd.DataFrame({'B_1':data_group_b.index, 'r1_mean_groupby_b':data_group_b})
data_group_b.head()
# Out:
#    B_1  r1_mean_groupby_b
# B
# 1    1         370.386921
# 2    2         140.877358
# 3    3         246.933778
# 4    4         583.627050
# 5    5         157.661571

# %%
#merge
data = data.merge(data_group_b, on =['B'], how = 'left')
data.head()
# Out:
#          BBLE  B  BLOCK BLDGCL TAXCLASS  LTFRONT  LTDEPTH  STORIES  \
# 0  1000010101  1      1     P7        4    500.0   1046.0     35.0
# 1  1000010201  1      1     Z9        4     27.0    355.0     35.0
# 2  1000020001  1      2     Y7        4    709.0    564.0      3.0
# 3  1000020023  1      2     T2        4    793.0    551.0      2.0
# 4  1000030001  1      3     Q1        4    323.0   1260.0      1.0
#
#        FULLVAL       AVLAND        ...          r1_byzip5 ZIP3  ZIP3_1  \
# 0   21400000.0    4225500.0        ...           0.129905  100     100
# 1  193800000.0   14310000.0        ...          64.191313  100     100
# 2  104686000.0   39008700.0        ...           0.831147  100     100
# 3   39200000.0   15255000.0        ...           0.284824  100     100
# 4  272300000.0  121050000.0        ...           2.124170  100     100
#
#    r1_mean_groupby_zip3  r1_byzip3  TAXCLASS_1  r1_mean_groupby_taxclass  \
# 0            380.454314   0.107550           4                268.124564
# 1            380.454314  53.144600           4                268.124564
# 2            380.454314   0.688115           4                268.124564
# 3            380.454314   0.235808           4                268.124564
# 4            380.454314   1.758620           4                268.124564
#
#    r1_bytaxclass  B_1  r1_mean_groupby_b
# 0       0.152607    1         370.386921
# 1      75.409325    1         370.386921
# 2       0.976398    1         370.386921
# 3       0.334599    1         370.386921
# 4       2.495387    1         370.386921
#
# [5 rows x 55 columns]

# %%
### Var4
data["r1_b"] = data["FULLVAL_r1"] / data["r1_mean_groupby_b"]
data.head()
# Out:
#          BBLE  B  BLOCK BLDGCL TAXCLASS  LTFRONT  LTDEPTH  STORIES  \
# 0  1000010101  1      1     P7        4    500.0   1046.0     35.0
# 1  1000010201  1      1     Z9        4     27.0    355.0     35.0
# 2  1000020001  1      2     Y7        4    709.0    564.0      3.0
# 3  1000020023  1      2     T2        4    793.0    551.0      2.0
# 4  1000030001  1      3     Q1        4    323.0   1260.0      1.0
#
#        FULLVAL       AVLAND    ...      ZIP3 ZIP3_1  r1_mean_groupby_zip3  \
# 0   21400000.0    4225500.0    ...       100    100            380.454314
# 1  193800000.0   14310000.0    ...       100    100            380.454314
# 2  104686000.0   39008700.0    ...       100    100            380.454314
# 3   39200000.0   15255000.0    ...       100    100            380.454314
# 4  272300000.0  121050000.0    ...       100    100            380.454314
#
#    r1_byzip3 TAXCLASS_1  r1_mean_groupby_taxclass  r1_bytaxclass  B_1  \
# 0   0.107550          4                268.124564       0.152607    1
# 1  53.144600          4                268.124564      75.409325    1
# 2   0.688115          4                268.124564       0.976398    1
# 3   0.235808          4                268.124564       0.334599    1
# 4   1.758620          4                268.124564       2.495387    1
#
#    r1_mean_groupby_b       r1_b
# 0         370.386921   0.110473
# 1         370.386921  54.589110
# 2         370.386921   0.706818
# 3         370.386921   0.242218
# 4         370.386921   1.806421
#
# [5 rows x 56 columns]

# %% [markdown]
# # r2 data["FULLVAL_r2"]

# %% [markdown]
# # var5

# %%
# r2 group by zip5
data_group_zip5_2 = data.groupby("ZIP")["FULLVAL_r2"].mean()
data_group_zip5_2 = pd.DataFrame({'ZIP5':data_group_zip5_2.index, 'r2_mean_groupby_zip5_2':data_group_zip5_2})
data_group_zip5_2.head()
# Out:
#             ZIP5  r2_mean_groupby_zip5_2
# ZIP
# 10001.0  10001.0             1179.476144
# 10002.0  10002.0              600.884831
# 10003.0  10003.0              845.949455
# 10004.0  10004.0              410.557233
# 10005.0  10005.0              117.230522

# %%
## create r2_mean_groupby_zip5 column
data = data.merge(data_group_zip5_2, on =['ZIP'], how = 'left')
data.head()
# Out:
#          BBLE  B  BLOCK BLDGCL TAXCLASS  LTFRONT  LTDEPTH  STORIES  \
# 0  1000010101  1      1     P7        4    500.0   1046.0     35.0
# 1  1000010201  1      1     Z9        4     27.0    355.0     35.0
# 2  1000020001  1      2     Y7        4    709.0    564.0      3.0
# 3  1000020023  1      2     T2        4    793.0    551.0      2.0
# 4  1000030001  1      3     Q1        4    323.0   1260.0      1.0
#
#        FULLVAL       AVLAND           ...            r1_mean_groupby_zip3  \
# 0   21400000.0    4225500.0           ...                      380.454314
# 1  193800000.0   14310000.0           ...                      380.454314
# 2  104686000.0   39008700.0           ...                      380.454314
# 3   39200000.0   15255000.0           ...                      380.454314
# 4  272300000.0  121050000.0           ...                      380.454314
#
#    r1_byzip3  TAXCLASS_1  r1_mean_groupby_taxclass r1_bytaxclass  B_1  \
# 0   0.107550           4                268.124564      0.152607    1
# 1  53.144600           4                268.124564     75.409325    1
# 2   0.688115           4                268.124564      0.976398    1
# 3   0.235808           4                268.124564      0.334599    1
# 4   1.758620           4                268.124564      2.495387    1
#
#    r1_mean_groupby_b       r1_b   ZIP5_y  r2_mean_groupby_zip5_2
# 0         370.386921   0.110473  10004.0              410.557233
# 1         370.386921  54.589110  10004.0              410.557233
# 2         370.386921   0.706818  10004.0              410.557233
# 3         370.386921   0.242218  10004.0              410.557233
# 4         370.386921   1.806421  10004.0              410.557233
#
# [5 rows x 58 columns]

# %%
### Var5
data["r2_byzip5"] = data["FULLVAL_r2"] / data["r2_mean_groupby_zip5_2"]
data.head()
# Out:
#          BBLE  B  BLOCK BLDGCL TAXCLASS  LTFRONT  LTDEPTH  STORIES  \
# 0  1000010101  1      1     P7        4    500.0   1046.0     35.0
# 1  1000010201  1      1     Z9        4     27.0    355.0     35.0
# 2  1000020001  1      2     Y7        4    709.0    564.0      3.0
# 3  1000020023  1      2     T2        4    793.0    551.0      2.0
# 4  1000030001  1      3     Q1        4    323.0   1260.0      1.0
#
#        FULLVAL       AVLAND     ...      r1_byzip3 TAXCLASS_1  \
# 0   21400000.0    4225500.0     ...       0.107550          4
# 1  193800000.0   14310000.0     ...      53.144600          4
# 2  104686000.0   39008700.0     ...       0.688115          4
# 3   39200000.0   15255000.0     ...       0.235808          4
# 4  272300000.0  121050000.0     ...       1.758620          4
#
#    r1_mean_groupby_taxclass  r1_bytaxclass B_1  r1_mean_groupby_b       r1_b  \
# 0                268.124564       0.152607   1         370.386921   0.110473
# 1                268.124564      75.409325   1         370.386921  54.589110
# 2                268.124564       0.976398   1         370.386921   0.706818
# 3                268.124564       0.334599   1         370.386921   0.242218
# 4                268.124564       2.495387   1         370.386921   1.806421
#
#     ZIP5_y  r2_mean_groupby_zip5_2   r2_byzip5
# 0  10004.0              410.557233    0.429091
# 1  10004.0              410.557233    3.885882
# 2  10004.0              410.557233    0.637661
# 3  10004.0              410.557233    2.038646
# 4  10004.0              410.557233  130.740178
#
# [5 rows x 59 columns]

# %% [markdown]
# # var 6 (r2 group by zip3)

# %%
# r6 group by zip3
data_group_zip3_2 = data.groupby("ZIP3")["FULLVAL_r2"].mean()
data_group_zip3_2 = pd.DataFrame({'ZIP3_1':data_group_zip3_2.index, 'r2_mean_groupby_zip3_2':data_group_zip3_2})

data = data.merge(data_group_zip3_2, on =['ZIP3'], how = 'left')

### Var6
data["r2_byzip3"] = data["FULLVAL_r2"] / data["r2_mean_groupby_zip3_2"]
data.head()
# Out:
#          BBLE  B  BLOCK BLDGCL TAXCLASS  LTFRONT  LTDEPTH  STORIES  \
# 0  1000010101  1      1     P7        4    500.0   1046.0     35.0
# 1  1000010201  1      1     Z9        4     27.0    355.0     35.0
# 2  1000020001  1      2     Y7        4    709.0    564.0      3.0
# 3  1000020023  1      2     T2        4    793.0    551.0      2.0
# 4  1000030001  1      3     Q1        4    323.0   1260.0      1.0
#
#        FULLVAL       AVLAND    ...      r1_bytaxclass B_1  r1_mean_groupby_b  \
# 0   21400000.0    4225500.0    ...           0.152607   1         370.386921
# 1  193800000.0   14310000.0    ...          75.409325   1         370.386921
# 2  104686000.0   39008700.0    ...           0.976398   1         370.386921
# 3   39200000.0   15255000.0    ...           0.334599   1         370.386921
# 4  272300000.0  121050000.0    ...           2.495387   1         370.386921
#
#         r1_b   ZIP5_y  r2_mean_groupby_zip5_2   r2_byzip5  ZIP3_1_y  \
# 0   0.110473  10004.0              410.557233    0.429091       100
# 1  54.589110  10004.0              410.557233    3.885882       100
# 2   0.706818  10004.0              410.557233    0.637661       100
# 3   0.242218  10004.0              410.557233    2.038646       100
# 4   1.806421  10004.0              410.557233  130.740178       100
#
#    r2_mean_groupby_zip3_2  r2_byzip3
# 0              579.581312   0.303955
# 1              579.581312   2.752637
# 2              579.581312   0.451699
# 3              579.581312   1.444113
# 4              579.581312  92.612244
#
# [5 rows x 62 columns]

# %% [markdown]
# # var 7 (r2 group by taxclass)

# %%
# r2 group by taxclass
data_group_taxclass_2 = data.groupby("TAXCLASS")["FULLVAL_r2"].mean()
data_group_taxclass_2 = pd.DataFrame({'TAXCLASS_1':data_group_taxclass_2.index, 'r2_mean_groupby_taxclass_2':data_group_taxclass_2})

#merge
data = data.merge(data_group_taxclass_2, on =['TAXCLASS'], how = 'left')

### Var3
data["r2_bytaxclass"] = data["FULLVAL_r2"] / data["r2_mean_groupby_taxclass_2"]
data.head()
# Out:
#          BBLE  B  BLOCK BLDGCL TAXCLASS  LTFRONT  LTDEPTH  STORIES  \
# 0  1000010101  1      1     P7        4    500.0   1046.0     35.0
# 1  1000010201  1      1     Z9        4     27.0    355.0     35.0
# 2  1000020001  1      2     Y7        4    709.0    564.0      3.0
# 3  1000020023  1      2     T2        4    793.0    551.0      2.0
# 4  1000030001  1      3     Q1        4    323.0   1260.0      1.0
#
#        FULLVAL       AVLAND      ...             r1_b   ZIP5_y  \
# 0   21400000.0    4225500.0      ...         0.110473  10004.0
# 1  193800000.0   14310000.0      ...        54.589110  10004.0
# 2  104686000.0   39008700.0      ...         0.706818  10004.0
# 3   39200000.0   15255000.0      ...         0.242218  10004.0
# 4  272300000.0  121050000.0      ...         1.806421  10004.0
#
#    r2_mean_groupby_zip5_2   r2_byzip5 ZIP3_1_y  r2_mean_groupby_zip3_2  \
# 0              410.557233    0.429091      100              579.581312
# 1              410.557233    3.885882      100              579.581312
# 2              410.557233    0.637661      100              579.581312
# 3              410.557233    2.038646      100              579.581312
# 4              410.557233  130.740178      100              579.581312
#
#    r2_byzip3  TAXCLASS_1_y  r2_mean_groupby_taxclass_2  r2_bytaxclass
# 0   0.303955             4                  813.804975       0.216473
# 1   2.752637             4                  813.804975       1.960392
# 2   0.451699             4                  813.804975       0.321694
# 3   1.444113             4                  813.804975       1.028478
# 4  92.612244             4                  813.804975      65.957235
#
# [5 rows x 65 columns]

# %% [markdown]
# # var 8 (r2 group by B)

# %%
# r2 group by B
data_group_b_2 = data.groupby("B")["FULLVAL_r2"].mean()
data_group_b_2 = pd.DataFrame({'B_1':data_group_b_2.index, 'r2_mean_groupby_b_2':data_group_b_2})

#merge
data = data.merge(data_group_b_2, on =['B'], how = 'left')

### Var8
data["r2_b"] = data["FULLVAL_r2"] / data["r2_mean_groupby_b_2"]
data.head()
# Out:
#          BBLE  B  BLOCK BLDGCL TAXCLASS  LTFRONT  LTDEPTH  STORIES  \
# 0  1000010101  1      1     P7        4    500.0   1046.0     35.0
# 1  1000010201  1      1     Z9        4     27.0    355.0     35.0
# 2  1000020001  1      2     Y7        4    709.0    564.0      3.0
# 3  1000020023  1      2     T2        4    793.0    551.0      2.0
# 4  1000030001  1      3     Q1        4    323.0   1260.0      1.0
#
#        FULLVAL       AVLAND    ...       r2_byzip5 ZIP3_1_y  \
# 0   21400000.0    4225500.0    ...        0.429091      100
# 1  193800000.0   14310000.0    ...        3.885882      100
# 2  104686000.0   39008700.0    ...        0.637661      100
# 3   39200000.0   15255000.0    ...        2.038646      100
# 4  272300000.0  121050000.0    ...      130.740178      100
#
#    r2_mean_groupby_zip3_2  r2_byzip3 TAXCLASS_1_y  r2_mean_groupby_taxclass_2  \
# 0              579.581312   0.303955            4                  813.804975
# 1              579.581312   2.752637            4                  813.804975
# 2              579.581312   0.451699            4                  813.804975
# 3              579.581312   1.444113            4                  813.804975
# 4              579.581312  92.612244            4                  813.804975
#
#    r2_bytaxclass  B_1_y  r2_mean_groupby_b_2       r2_b
# 0       0.216473      1           563.083825   0.312860
# 1       1.960392      1           563.083825   2.833285
# 2       0.321694      1           563.083825   0.464933
# 3       1.028478      1           563.083825   1.486423
# 4      65.957235      1           563.083825  95.325639
#
# [5 rows x 68 columns]

# %% [markdown]
# # var 9 (r3 group by zip5)

# %%
# r3 group by zip5
data_group_zip5_3 = data.groupby("ZIP")["FULLVAL_r3"].mean()
data_group_zip5_3 = pd.DataFrame({'ZIP5':data_group_zip5_3.index, 'r3_mean_groupby_zip5_3':data_group_zip5_3})

## create r3_mean_groupby_zip5 column
data = data.merge(data_group_zip5_3, on =['ZIP'], how = 'left')

### Var9
data["r3_byzip5"] = data["FULLVAL_r3"] / data["r3_mean_groupby_zip5_3"]
data.head()
# Out:
#          BBLE  B  BLOCK BLDGCL TAXCLASS  LTFRONT  LTDEPTH  STORIES  \
# 0  1000010101  1      1     P7        4    500.0   1046.0     35.0
# 1  1000010201  1      1     Z9        4     27.0    355.0     35.0
# 2  1000020001  1      2     Y7        4    709.0    564.0      3.0
# 3  1000020023  1      2     T2        4    793.0    551.0      2.0
# 4  1000030001  1      3     Q1        4    323.0   1260.0      1.0
#
#        FULLVAL       AVLAND     ...      r2_byzip3 TAXCLASS_1_y  \
# 0   21400000.0    4225500.0     ...       0.303955            4
# 1  193800000.0   14310000.0     ...       2.752637            4
# 2  104686000.0   39008700.0     ...       0.451699            4
# 3   39200000.0   15255000.0     ...       1.444113            4
# 4  272300000.0  121050000.0     ...      92.612244            4
#
#    r2_mean_groupby_taxclass_2  r2_bytaxclass B_1_y  r2_mean_groupby_b_2  \
# 0                  813.804975       0.216473     1           563.083825
# 1                  813.804975       1.960392     1           563.083825
# 2                  813.804975       0.321694     1           563.083825
# 3                  813.804975       1.028478     1           563.083825
# 4                  813.804975      65.957235     1           563.083825
#
#         r2_b     ZIP5  r3_mean_groupby_zip5_3   r3_byzip5
# 0   0.312860  10004.0              135.032202    0.037275
# 1   2.833285  10004.0              135.032202    0.337565
# 2   0.464933  10004.0              135.032202    0.646256
# 3   1.486423  10004.0              135.032202    3.099190
# 4  95.325639  10004.0              135.032202  397.507594
#
# [5 rows x 71 columns]

# %% [markdown]
# # var 10 (r3 group by zip3)

# %%
data_group_zip3_3 = data.groupby("ZIP3")["FULLVAL_r3"].mean()
data_group_zip3_3 = pd.DataFrame({'ZIP3_3':data_group_zip3_3.index, 'r3_mean_groupby_zip3_3':data_group_zip3_3})

data = data.merge(data_group_zip3_3, on =['ZIP3'], how = 'left')

### Var6
data["r3_byzip3"] = data["FULLVAL_r3"] / data["r3_mean_groupby_zip3_3"]
data.head()
# Out:
#          BBLE  B  BLOCK BLDGCL TAXCLASS  LTFRONT  LTDEPTH  STORIES  \
# 0  1000010101  1      1     P7        4    500.0   1046.0     35.0
# 1  1000010201  1      1     Z9        4     27.0    355.0     35.0
# 2  1000020001  1      2     Y7        4    709.0    564.0      3.0
# 3  1000020023  1      2     T2        4    793.0    551.0      2.0
# 4  1000030001  1      3     Q1        4    323.0   1260.0      1.0
#
#        FULLVAL       AVLAND     ...      r2_bytaxclass B_1_y  \
# 0   21400000.0    4225500.0     ...           0.216473     1
# 1  193800000.0   14310000.0     ...           1.960392     1
# 2  104686000.0   39008700.0     ...           0.321694     1
# 3   39200000.0   15255000.0     ...           1.028478     1
# 4  272300000.0  121050000.0     ...          65.957235     1
#
#    r2_mean_groupby_b_2       r2_b     ZIP5  r3_mean_groupby_zip5_3  \
# 0           563.083825   0.312860  10004.0              135.032202
# 1           563.083825   2.833285  10004.0              135.032202
# 2           563.083825   0.464933  10004.0              135.032202
# 3           563.083825   1.486423  10004.0              135.032202
# 4           563.083825  95.325639  10004.0              135.032202
#
#     r3_byzip5  ZIP3_3  r3_mean_groupby_zip3_3   r3_byzip3
# 0    0.037275     100              148.830894    0.033819
# 1    0.337565     100              148.830894    0.306268
# 2    0.646256     100              148.830894    0.586339
# 3    3.099190     100              148.830894    2.811852
# 4  397.507594     100              148.830894  360.653117
#
# [5 rows x 74 columns]

# %% [markdown]
# # var 11 (r3 group by taxclass)

# %%
# r3 group by taxclass
data_group_taxclass_3 = data.groupby("TAXCLASS")["FULLVAL_r3"].mean()
data_group_taxclass_3 = pd.DataFrame({'TAXCLASS_3':data_group_taxclass_3.index, 'r3_mean_groupby_taxclass_3':data_group_taxclass_3})

#merge
data = data.merge(data_group_taxclass_3, on =['TAXCLASS'], how = 'left')

### Var3
data["r3_bytaxclass"] = data["FULLVAL_r3"] / data["r3_mean_groupby_taxclass_3"]
data.head()
# Out:
#          BBLE  B  BLOCK BLDGCL TAXCLASS  LTFRONT  LTDEPTH  STORIES  \
# 0  1000010101  1      1     P7        4    500.0   1046.0     35.0
# 1  1000010201  1      1     Z9        4     27.0    355.0     35.0
# 2  1000020001  1      2     Y7        4    709.0    564.0      3.0
# 3  1000020023  1      2     T2        4    793.0    551.0      2.0
# 4  1000030001  1      3     Q1        4    323.0   1260.0      1.0
#
#        FULLVAL       AVLAND      ...             r2_b     ZIP5  \
# 0   21400000.0    4225500.0      ...         0.312860  10004.0
# 1  193800000.0   14310000.0      ...         2.833285  10004.0
# 2  104686000.0   39008700.0      ...         0.464933  10004.0
# 3   39200000.0   15255000.0      ...         1.486423  10004.0
# 4  272300000.0  121050000.0      ...        95.325639  10004.0
#
#    r3_mean_groupby_zip5_3   r3_byzip5 ZIP3_3  r3_mean_groupby_zip3_3  \
# 0              135.032202    0.037275    100              148.830894
# 1              135.032202    0.337565    100              148.830894
# 2              135.032202    0.646256    100              148.830894
# 3              135.032202    3.099190    100              148.830894
# 4              135.032202  397.507594    100              148.830894
#
#     r3_byzip3  TAXCLASS_3  r3_mean_groupby_taxclass_3  r3_bytaxclass
# 0    0.033819           4                  359.618927       0.013996
# 1    0.306268           4                  359.618927       0.126751
# 2    0.586339           4                  359.618927       0.242661
# 3    2.811852           4                  359.618927       1.163705
# 4  360.653117           4                  359.618927     149.258900
#
# [5 rows x 77 columns]

# %% [markdown]
# # var 12 (r3 group by b)

# %%
# r3 group by B
data_group_b_3 = data.groupby("B")["FULLVAL_r3"].mean()
data_group_b_3 = pd.DataFrame({'B_3':data_group_b_3.index, 'r3_mean_groupby_b_3':data_group_b_3})

#merge
data = data.merge(data_group_b_3, on =['B'], how = 'left')

### Var12
data["r3_b"] = data["FULLVAL_r3"] / data["r3_mean_groupby_b_3"]
data.head()
# Out:
#          BBLE  B  BLOCK BLDGCL TAXCLASS  LTFRONT  LTDEPTH  STORIES  \
# 0  1000010101  1      1     P7        4    500.0   1046.0     35.0
# 1  1000010201  1      1     Z9        4     27.0    355.0     35.0
# 2  1000020001  1      2     Y7        4    709.0    564.0      3.0
# 3  1000020023  1      2     T2        4    793.0    551.0      2.0
# 4  1000030001  1      3     Q1        4    323.0   1260.0      1.0
#
#        FULLVAL       AVLAND     ...       r3_byzip5 ZIP3_3  \
# 0   21400000.0    4225500.0     ...        0.037275    100
# 1  193800000.0   14310000.0     ...        0.337565    100
# 2  104686000.0   39008700.0     ...        0.646256    100
# 3   39200000.0   15255000.0     ...        3.099190    100
# 4  272300000.0  121050000.0     ...      397.507594    100
#
#    r3_mean_groupby_zip3_3   r3_byzip3 TAXCLASS_3  r3_mean_groupby_taxclass_3  \
# 0              148.830894    0.033819          4                  359.618927
# 1              148.830894    0.306268          4                  359.618927
# 2              148.830894    0.586339          4                  359.618927
# 3              148.830894    2.811852          4                  359.618927
# 4              148.830894  360.653117          4                  359.618927
#
#    r3_bytaxclass  B_3  r3_mean_groupby_b_3        r3_b
# 0       0.013996    1           144.062833    0.034938
# 1       0.126751    1           144.062833    0.316405
# 2       0.242661    1           144.062833    0.605745
# 3       1.163705    1           144.062833    2.904916
# 4     149.258900    1           144.062833  372.589685
#
# [5 rows x 80 columns]

# %% [markdown]
# # var 13 (r4 group by zip5)

# %%
# r group by zip5
data_group_zip5_4 = data.groupby("ZIP")["AVLAND_r4"].mean()
data_group_zip5_4 = pd.DataFrame({'ZIP5_4':data_group_zip5_4.index, 'r4_mean_groupby_zip5_4':data_group_zip5_4})

## create r4_mean_groupby_zip5 column
data = data.merge(data_group_zip5_4, on =['ZIP'], how = 'left')

### Var5
data["r4_byzip5"] = data["AVLAND_r4"] / data["r4_mean_groupby_zip5_4"]
data.head()
# Out:
#          BBLE  B  BLOCK BLDGCL TAXCLASS  LTFRONT  LTDEPTH  STORIES  \
# 0  1000010101  1      1     P7        4    500.0   1046.0     35.0
# 1  1000010201  1      1     Z9        4     27.0    355.0     35.0
# 2  1000020001  1      2     Y7        4    709.0    564.0      3.0
# 3  1000020023  1      2     T2        4    793.0    551.0      2.0
# 4  1000030001  1      3     Q1        4    323.0   1260.0      1.0
#
#        FULLVAL       AVLAND    ...       r3_byzip3 TAXCLASS_3  \
# 0   21400000.0    4225500.0    ...        0.033819          4
# 1  193800000.0   14310000.0    ...        0.306268          4
# 2  104686000.0   39008700.0    ...        0.586339          4
# 3   39200000.0   15255000.0    ...        2.811852          4
# 4  272300000.0  121050000.0    ...      360.653117          4
#
#    r3_mean_groupby_taxclass_3  r3_bytaxclass B_3  r3_mean_groupby_b_3  \
# 0                  359.618927       0.013996   1           144.062833
# 1                  359.618927       0.126751   1           144.062833
# 2                  359.618927       0.242661   1           144.062833
# 3                  359.618927       1.163705   1           144.062833
# 4                  359.618927     149.258900   1           144.062833
#
#          r3_b   ZIP5_4  r4_mean_groupby_zip5_4  r4_byzip5
# 0    0.034938  10004.0               44.914391   0.179883
# 1    0.316405  10004.0               44.914391  33.240076
# 2    0.605745  10004.0               44.914391   2.171954
# 3    2.904916  10004.0               44.914391   0.777324
# 4  372.589685  10004.0               44.914391   6.622260
#
# [5 rows x 83 columns]

# %% [markdown]
# # var 14 (r4 group by zip3)

# %%
data_group_zip3_4 = data.groupby("ZIP3")["AVLAND_r4"].mean()
data_group_zip3_4 = pd.DataFrame({'ZIP3_4':data_group_zip3_4.index, 'r4_mean_groupby_zip3_4':data_group_zip3_4})

data = data.merge(data_group_zip3_4, on =['ZIP3'], how = 'left')

### Var14
data["r4_byzip3"] = data["AVLAND_r4"] / data["r4_mean_groupby_zip3_4"]
data.head()
# Out:
#          BBLE  B  BLOCK BLDGCL TAXCLASS  LTFRONT  LTDEPTH  STORIES  \
# 0  1000010101  1      1     P7        4    500.0   1046.0     35.0
# 1  1000010201  1      1     Z9        4     27.0    355.0     35.0
# 2  1000020001  1      2     Y7        4    709.0    564.0      3.0
# 3  1000020023  1      2     T2        4    793.0    551.0      2.0
# 4  1000030001  1      3     Q1        4    323.0   1260.0      1.0
#
#        FULLVAL       AVLAND    ...      r3_bytaxclass B_3  \
# 0   21400000.0    4225500.0    ...           0.013996   1
# 1  193800000.0   14310000.0    ...           0.126751   1
# 2  104686000.0   39008700.0    ...           0.242661   1
# 3   39200000.0   15255000.0    ...           1.163705   1
# 4  272300000.0  121050000.0    ...         149.258900   1
#
#    r3_mean_groupby_b_3        r3_b   ZIP5_4  r4_mean_groupby_zip5_4  \
# 0           144.062833    0.034938  10004.0               44.914391
# 1           144.062833    0.316405  10004.0               44.914391
# 2           144.062833    0.605745  10004.0               44.914391
# 3           144.062833    2.904916  10004.0               44.914391
# 4           144.062833  372.589685  10004.0               44.914391
#
#    r4_byzip5  ZIP3_4  r4_mean_groupby_zip3_4  r4_byzip3
# 0   0.179883     100               37.206895   0.217147
# 1  33.240076     100               37.206895  40.125836
# 2   2.171954     100               37.206895   2.621879
# 3   0.777324     100               37.206895   0.938348
# 4   6.622260     100               37.206895   7.994076
#
# [5 rows x 86 columns]

# %% [markdown]
# # var 15 (r4 group by taxclass)

# %%
# r15 group by taxclass
data_group_taxclass_4 = data.groupby("TAXCLASS")["AVLAND_r4"].mean()
data_group_taxclass_4 = pd.DataFrame({'TAXCLASS_4':data_group_taxclass_4.index, 'r4_mean_groupby_taxclass_4':data_group_taxclass_4})

#merge
data = data.merge(data_group_taxclass_4, on =['TAXCLASS'], how = 'left')

### Var3
data["r4_bytaxclass"] = data["AVLAND_r4"] / data["r4_mean_groupby_taxclass_4"]
data.head()
# Out:
#          BBLE  B  BLOCK BLDGCL TAXCLASS  LTFRONT  LTDEPTH  STORIES  \
# 0  1000010101  1      1     P7        4    500.0   1046.0     35.0
# 1  1000010201  1      1     Z9        4     27.0    355.0     35.0
# 2  1000020001  1      2     Y7        4    709.0    564.0      3.0
# 3  1000020023  1      2     T2        4    793.0    551.0      2.0
# 4  1000030001  1      3     Q1        4    323.0   1260.0      1.0
#
#        FULLVAL       AVLAND      ...              r3_b   ZIP5_4  \
# 0   21400000.0    4225500.0      ...          0.034938  10004.0
# 1  193800000.0   14310000.0      ...          0.316405  10004.0
# 2  104686000.0   39008700.0      ...          0.605745  10004.0
# 3   39200000.0   15255000.0      ...          2.904916  10004.0
# 4  272300000.0  121050000.0      ...        372.589685  10004.0
#
#    r4_mean_groupby_zip5_4  r4_byzip5 ZIP3_4  r4_mean_groupby_zip3_4  \
# 0               44.914391   0.179883    100               37.206895
# 1               44.914391  33.240076    100               37.206895
# 2               44.914391   2.171954    100               37.206895
# 3               44.914391   0.777324    100               37.206895
# 4               44.914391   6.622260    100               37.206895
#
#    r4_byzip3  TAXCLASS_4  r4_mean_groupby_taxclass_4  r4_bytaxclass
# 0   0.217147           4                   51.301092       0.157489
# 1  40.125836           4                   51.301092      29.101870
# 2   2.621879           4                   51.301092       1.901558
# 3   0.938348           4                   51.301092       0.680551
# 4   7.994076           4                   51.301092       5.797825
#
# [5 rows x 89 columns]

# %% [markdown]
# # var 16 (r4 group by b)

# %%
# r4 group by B
data_group_b_4 = data.groupby("B")["AVLAND_r4"].mean()
data_group_b_4 = pd.DataFrame({'B_4':data_group_b_4.index, 'r4_mean_groupby_b_4':data_group_b_4})

#merge
data = data.merge(data_group_b_4, on =['B'], how = 'left')

### Var16
data["r4_b"] = data["AVLAND_r4"] / data["r4_mean_groupby_b_4"]
data.head()
# Out:
#          BBLE  B  BLOCK BLDGCL TAXCLASS  LTFRONT  LTDEPTH  STORIES  \
# 0  1000010101  1      1     P7        4    500.0   1046.0     35.0
# 1  1000010201  1      1     Z9        4     27.0    355.0     35.0
# 2  1000020001  1      2     Y7        4    709.0    564.0      3.0
# 3  1000020023  1      2     T2        4    793.0    551.0      2.0
# 4  1000030001  1      3     Q1        4    323.0   1260.0      1.0
#
#        FULLVAL       AVLAND    ...      r4_byzip5 ZIP3_4  \
# 0   21400000.0    4225500.0    ...       0.179883    100
# 1  193800000.0   14310000.0    ...      33.240076    100
# 2  104686000.0   39008700.0    ...       2.171954    100
# 3   39200000.0   15255000.0    ...       0.777324    100
# 4  272300000.0  121050000.0    ...       6.622260    100
#
#    r4_mean_groupby_zip3_4  r4_byzip3 TAXCLASS_4  r4_mean_groupby_taxclass_4  \
# 0               37.206895   0.217147          4                   51.301092
# 1               37.206895  40.125836          4                   51.301092
# 2               37.206895   2.621879          4                   51.301092
# 3               37.206895   0.938348          4                   51.301092
# 4               37.206895   7.994076          4                   51.301092
#
#    r4_bytaxclass  B_4  r4_mean_groupby_b_4       r4_b
# 0       0.157489    1            35.811386   0.225608
# 1      29.101870    1            35.811386  41.689471
# 2       1.901558    1            35.811386   2.724050
# 3       0.680551    1            35.811386   0.974914
# 4       5.797825    1            35.811386   8.305592
#
# [5 rows x 92 columns]

# %% [markdown]
# # var 17 (r5 group by zip5)

# %%
# r group by zip5
data_group_zip5_5 = data.groupby("ZIP")["AVLAND_r5"].mean()
data_group_zip5_5 = pd.DataFrame({'ZIP5_5':data_group_zip5_5.index, 'r5_mean_groupby_zip5_5':data_group_zip5_5})

## create r4_mean_groupby_zip5 column
data = data.merge(data_group_zip5_5, on =['ZIP'], how = 'left')

### Var17
data["r5_byzip5"] = data["AVLAND_r5"] / data["r5_mean_groupby_zip5_5"]
data.head()
# Out:
#          BBLE  B  BLOCK BLDGCL TAXCLASS  LTFRONT  LTDEPTH  STORIES  \
# 0  1000010101  1      1     P7        4    500.0   1046.0     35.0
# 1  1000010201  1      1     Z9        4     27.0    355.0     35.0
# 2  1000020001  1      2     Y7        4    709.0    564.0      3.0
# 3  1000020023  1      2     T2        4    793.0    551.0      2.0
# 4  1000030001  1      3     Q1        4    323.0   1260.0      1.0
#
#        FULLVAL       AVLAND     ...      r4_byzip3 TAXCLASS_4  \
# 0   21400000.0    4225500.0     ...       0.217147          4
# 1  193800000.0   14310000.0     ...      40.125836          4
# 2  104686000.0   39008700.0     ...       2.621879          4
# 3   39200000.0   15255000.0     ...       0.938348          4
# 4  272300000.0  121050000.0     ...       7.994076          4
#
#    r4_mean_groupby_taxclass_4  r4_bytaxclass B_4  r4_mean_groupby_b_4  \
# 0                   51.301092       0.157489   1            35.811386
# 1                   51.301092      29.101870   1            35.811386
# 2                   51.301092       1.901558   1            35.811386
# 3                   51.301092       0.680551   1            35.811386
# 4                   51.301092       5.797825   1            35.811386
#
#         r4_b   ZIP5_5  r5_mean_groupby_zip5_5   r5_byzip5
# 0   0.225608  10004.0                92.21097    0.377229
# 1  41.689471  10004.0                92.21097    1.277517
# 2   2.724050  10004.0                92.21097    1.057922
# 3   0.974914  10004.0                92.21097    3.532312
# 4   8.305592  10004.0                92.21097  258.772036
#
# [5 rows x 95 columns]

# %% [markdown]
# # var 18 (r5 group by zip3)

# %%
data_group_zip3_5 = data.groupby("ZIP3")["AVLAND_r5"].mean()
data_group_zip3_5 = pd.DataFrame({'ZIP3_5':data_group_zip3_5.index, 'r5_mean_groupby_zip3_5':data_group_zip3_5})

data = data.merge(data_group_zip3_5, on =['ZIP3'], how = 'left')

### Var14
data["r5_byzip3"] = data["AVLAND_r5"] / data["r5_mean_groupby_zip3_5"]
data.head()
# Out:
#          BBLE  B  BLOCK BLDGCL TAXCLASS  LTFRONT  LTDEPTH  STORIES  \
# 0  1000010101  1      1     P7        4    500.0   1046.0     35.0
# 1  1000010201  1      1     Z9        4     27.0    355.0     35.0
# 2  1000020001  1      2     Y7        4    709.0    564.0      3.0
# 3  1000020023  1      2     T2        4    793.0    551.0      2.0
# 4  1000030001  1      3     Q1        4    323.0   1260.0      1.0
#
#        FULLVAL       AVLAND     ...      r4_bytaxclass B_4  \
# 0   21400000.0    4225500.0     ...           0.157489   1
# 1  193800000.0   14310000.0     ...          29.101870   1
# 2  104686000.0   39008700.0     ...           1.901558   1
# 3   39200000.0   15255000.0     ...           0.680551   1
# 4  272300000.0  121050000.0     ...           5.797825   1
#
#    r4_mean_groupby_b_4       r4_b   ZIP5_5  r5_mean_groupby_zip5_5  \
# 0            35.811386   0.225608  10004.0                92.21097
# 1            35.811386  41.689471  10004.0                92.21097
# 2            35.811386   2.724050  10004.0                92.21097
# 3            35.811386   0.974914  10004.0                92.21097
# 4            35.811386   8.305592  10004.0                92.21097
#
#     r5_byzip5  ZIP3_5  r5_mean_groupby_zip3_5   r5_byzip3
# 0    0.377229     100               72.044036    0.482825
# 1    1.277517     100               72.044036    1.635126
# 2    1.057922     100               72.044036    1.354061
# 3    3.532312     100               72.044036    4.521095
# 4  258.772036     100               72.044036  331.208824
#
# [5 rows x 98 columns]

# %% [markdown]
# # var 19 (r5 group by taxclass)

# %%
# r5 group by taxclass
data_group_taxclass_5 = data.groupby("TAXCLASS")["AVLAND_r5"].mean()
data_group_taxclass_5 = pd.DataFrame({'TAXCLASS_5':data_group_taxclass_5.index, 'r5_mean_groupby_taxclass_5':data_group_taxclass_5})

#merge
data = data.merge(data_group_taxclass_5, on =['TAXCLASS'], how = 'left')

### Var19
data["r5_bytaxclass"] = data["AVLAND_r5"] / data["r5_mean_groupby_taxclass_5"]
data.head()
# Out:
#          BBLE  B  BLOCK BLDGCL TAXCLASS  LTFRONT  LTDEPTH  STORIES  \
# 0  1000010101  1      1     P7        4    500.0   1046.0     35.0
# 1  1000010201  1      1     Z9        4     27.0    355.0     35.0
# 2  1000020001  1      2     Y7        4    709.0    564.0      3.0
# 3  1000020023  1      2     T2        4    793.0    551.0      2.0
# 4  1000030001  1      3     Q1        4    323.0   1260.0      1.0
#
#        FULLVAL       AVLAND      ...             r4_b   ZIP5_5  \
# 0   21400000.0    4225500.0      ...         0.225608  10004.0
# 1  193800000.0   14310000.0      ...        41.689471  10004.0
# 2  104686000.0   39008700.0      ...         2.724050  10004.0
# 3   39200000.0   15255000.0      ...         0.974914  10004.0
# 4  272300000.0  121050000.0      ...         8.305592  10004.0
#
#    r5_mean_groupby_zip5_5   r5_byzip5 ZIP3_5  r5_mean_groupby_zip3_5  \
# 0                92.21097    0.377229    100               72.044036
# 1                92.21097    1.277517    100               72.044036
# 2                92.21097    1.057922    100               72.044036
# 3                92.21097    3.532312    100               72.044036
# 4                92.21097  258.772036    100               72.044036
#
#     r5_byzip3  TAXCLASS_5  r5_mean_groupby_taxclass_5  r5_bytaxclass
# 0    0.482825           4                  252.613268       0.137699
# 1    1.635126           4                  252.613268       0.466330
# 2    1.354061           4                  252.613268       0.386171
# 3    4.521095           4                  252.613268       1.289394
# 4  331.208824           4                  252.613268      94.459094
#
# [5 rows x 101 columns]

# %% [markdown]
# # var 20 (r5 group by b)

# %%
# r5 group by B
data_group_b_5 = data.groupby("B")["AVLAND_r5"].mean()
data_group_b_5 = pd.DataFrame({'B_5':data_group_b_5.index, 'r5_mean_groupby_b_5':data_group_b_5})

#merge
data = data.merge(data_group_b_5, on =['B'], how = 'left')

### Var20
data["r5_b"] = data["AVLAND_r5"] / data["r5_mean_groupby_b_5"]

# %% [markdown]
# # var 21 (r6 group by zip5)

# %%
# r6 group by zip5
data_group_zip5_6 = data.groupby("ZIP")["AVLAND_r6"].mean()
data_group_zip5_6 = pd.DataFrame({'ZIP5_6':data_group_zip5_6.index, 'r6_mean_groupby_zip5_6':data_group_zip5_6})

## create r4_mean_groupby_zip5 column
data = data.merge(data_group_zip5_6, on =['ZIP'], how = 'left')

### Var17
data["r6_byzip5"] = data["AVLAND_r6"] / data["r6_mean_groupby_zip5_6"]
data.head()
# Out:
#          BBLE  B  BLOCK BLDGCL TAXCLASS  LTFRONT  LTDEPTH  STORIES  \
# 0  1000010101  1      1     P7        4    500.0   1046.0     35.0
# 1  1000010201  1      1     Z9        4     27.0    355.0     35.0
# 2  1000020001  1      2     Y7        4    709.0    564.0      3.0
# 3  1000020023  1      2     T2        4    793.0    551.0      2.0
# 4  1000030001  1      3     Q1        4    323.0   1260.0      1.0
#
#        FULLVAL       AVLAND     ...       r5_byzip3 TAXCLASS_5  \
# 0   21400000.0    4225500.0     ...        0.482825          4
# 1  193800000.0   14310000.0     ...        1.635126          4
# 2  104686000.0   39008700.0     ...        1.354061          4
# 3   39200000.0   15255000.0     ...        4.521095          4
# 4  272300000.0  121050000.0     ...      331.208824          4
#
#    r5_mean_groupby_taxclass_5  r5_bytaxclass B_5  r5_mean_groupby_b_5  \
# 0                  252.613268       0.137699   1            68.968859
# 1                  252.613268       0.466330   1            68.968859
# 2                  252.613268       0.386171   1            68.968859
# 3                  252.613268       1.289394   1            68.968859
# 4                  252.613268      94.459094   1            68.968859
#
#          r5_b   ZIP5_6  r6_mean_groupby_zip5_6   r6_byzip5
# 0    0.504353  10004.0               51.898701    0.019150
# 1    1.708032  10004.0               51.898701    0.064852
# 2    1.414435  10004.0               51.898701    0.626554
# 3    4.722681  10004.0               51.898701    3.138016
# 4  345.976729  10004.0               51.898701  459.772975
#
# [5 rows x 107 columns]

# %% [markdown]
# # var 22 (r6 group by zip3)

# %%
data_group_zip3_6 = data.groupby("ZIP3")["AVLAND_r6"].mean()
data_group_zip3_6 = pd.DataFrame({'ZIP3_5':data_group_zip3_6.index, 'r6_mean_groupby_zip3_6':data_group_zip3_6})

data = data.merge(data_group_zip3_6, on =['ZIP3'], how = 'left')

### Var22
data["r6_byzip3"] = data["AVLAND_r6"] / data["r6_mean_groupby_zip3_6"]
data.head()
# Out:
#          BBLE  B  BLOCK BLDGCL TAXCLASS  LTFRONT  LTDEPTH  STORIES  \
# 0  1000010101  1      1     P7        4    500.0   1046.0     35.0
# 1  1000010201  1      1     Z9        4     27.0    355.0     35.0
# 2  1000020001  1      2     Y7        4    709.0    564.0      3.0
# 3  1000020023  1      2     T2        4    793.0    551.0      2.0
# 4  1000030001  1      3     Q1        4    323.0   1260.0      1.0
#
#        FULLVAL       AVLAND     ...      r5_bytaxclass B_5  \
# 0   21400000.0    4225500.0     ...           0.137699   1
# 1  193800000.0   14310000.0     ...           0.466330   1
# 2  104686000.0   39008700.0     ...           0.386171   1
# 3   39200000.0   15255000.0     ...           1.289394   1
# 4  272300000.0  121050000.0     ...          94.459094   1
#
#    r5_mean_groupby_b_5        r5_b   ZIP5_6  r6_mean_groupby_zip5_6  \
# 0            68.968859    0.504353  10004.0               51.898701
# 1            68.968859    1.708032  10004.0               51.898701
# 2            68.968859    1.414435  10004.0               51.898701
# 3            68.968859    4.722681  10004.0               51.898701
# 4            68.968859  345.976729  10004.0               51.898701
#
#     r6_byzip5  ZIP3_5_y  r6_mean_groupby_zip3_6   r6_byzip3
# 0    0.019150       100               25.046372    0.039680
# 1    0.064852       100               25.046372    0.134381
# 2    0.626554       100               25.046372    1.298285
# 3    3.138016       100               25.046372    6.502298
# 4  459.772975       100               25.046372  952.697664
#
# [5 rows x 110 columns]

# %% [markdown]
# # var 23 (r6 group by taxclass)

# %%
# r6 group by taxclass
data_group_taxclass_6 = data.groupby("TAXCLASS")["AVLAND_r6"].mean()
data_group_taxclass_6 = pd.DataFrame({'TAXCLASS_6':data_group_taxclass_6.index, 'r6_mean_groupby_taxclass_6':data_group_taxclass_6})

#merge
data = data.merge(data_group_taxclass_6, on =['TAXCLASS'], how = 'left')

### Var23
data["r6_bytaxclass"] = data["AVLAND_r6"] / data["r6_mean_groupby_taxclass_6"]
data.head()
# Out:
#          BBLE  B  BLOCK BLDGCL TAXCLASS  LTFRONT  LTDEPTH  STORIES  \
# 0  1000010101  1      1     P7        4    500.0   1046.0     35.0
# 1  1000010201  1      1     Z9        4     27.0    355.0     35.0
# 2  1000020001  1      2     Y7        4    709.0    564.0      3.0
# 3  1000020023  1      2     T2        4    793.0    551.0      2.0
# 4  1000030001  1      3     Q1        4    323.0   1260.0      1.0
#
#        FULLVAL       AVLAND      ...              r5_b   ZIP5_6  \
# 0   21400000.0    4225500.0      ...          0.504353  10004.0
# 1  193800000.0   14310000.0      ...          1.708032  10004.0
# 2  104686000.0   39008700.0      ...          1.414435  10004.0
# 3   39200000.0   15255000.0      ...          4.722681  10004.0
# 4  272300000.0  121050000.0      ...        345.976729  10004.0
#
#    r6_mean_groupby_zip5_6   r6_byzip5 ZIP3_5_y  r6_mean_groupby_zip3_6  \
# 0               51.898701    0.019150      100               25.046372
# 1               51.898701    0.064852      100               25.046372
# 2               51.898701    0.626554      100               25.046372
# 3               51.898701    3.138016      100               25.046372
# 4               51.898701  459.772975      100               25.046372
#
#     r6_byzip3  TAXCLASS_6  r6_mean_groupby_taxclass_6  r6_bytaxclass
# 0    0.039680           4                  124.797333       0.007964
# 1    0.134381           4                  124.797333       0.026970
# 2    1.298285           4                  124.797333       0.260561
# 3    6.502298           4                  124.797333       1.304988
# 4  952.697664           4                  124.797333     191.202967
#
# [5 rows x 113 columns]

# %% [markdown]
# # var 24 (r6 group by b)

# %%
# r6 group by B
data_group_b_6 = data.groupby("B")["AVLAND_r6"].mean()
data_group_b_6 = pd.DataFrame({'B_6':data_group_b_6.index, 'r6_mean_groupby_b_6':data_group_b_6})

#merge
data = data.merge(data_group_b_6, on =['B'], how = 'left')

### Var20
data["r6_b"] = data["AVLAND_r6"] / data["r6_mean_groupby_b_6"]
data.head()
# Out:
#          BBLE  B  BLOCK BLDGCL TAXCLASS  LTFRONT  LTDEPTH  STORIES  \
# 0  1000010101  1      1     P7        4    500.0   1046.0     35.0
# 1  1000010201  1      1     Z9        4     27.0    355.0     35.0
# 2  1000020001  1      2     Y7        4    709.0    564.0      3.0
# 3  1000020023  1      2     T2        4    793.0    551.0      2.0
# 4  1000030001  1      3     Q1        4    323.0   1260.0      1.0
#
#        FULLVAL       AVLAND     ...        r6_byzip5 ZIP3_5_y  \
# 0   21400000.0    4225500.0     ...         0.019150      100
# 1  193800000.0   14310000.0     ...         0.064852      100
# 2  104686000.0   39008700.0     ...         0.626554      100
# 3   39200000.0   15255000.0     ...         3.138016      100
# 4  272300000.0  121050000.0     ...       459.772975      100
#
#    r6_mean_groupby_zip3_6   r6_byzip3 TAXCLASS_6  r6_mean_groupby_taxclass_6  \
# 0               25.046372    0.039680          4                  124.797333
# 1               25.046372    0.134381          4                  124.797333
# 2               25.046372    1.298285          4                  124.797333
# 3               25.046372    6.502298          4                  124.797333
# 4               25.046372  952.697664          4                  124.797333
#
#    r6_bytaxclass  B_6  r6_mean_groupby_b_6         r6_b
# 0       0.007964    1             23.71018     0.041916
# 1       0.026970    1             23.71018     0.141954
# 2       0.260561    1             23.71018     1.371450
# 3       1.304988    1             23.71018     6.868736
# 4     191.202967    1             23.71018  1006.387148
#
# [5 rows x 116 columns]

# %% [markdown]
# # AVTOT
# # var 25 (r7 group by zip5)

# %%
# r6 group by zip5
data_group_zip5_7 = data.groupby("ZIP")["AVTOT_r7"].mean()
data_group_zip5_7 = pd.DataFrame({'ZIP5_7':data_group_zip5_7.index, 'r7_mean_groupby_zip5_7':data_group_zip5_7})

## create r7_mean_groupby_zip5 column
data = data.merge(data_group_zip5_7, on =['ZIP'], how = 'left')

### Var17
data["r7_byzip5"] = data["AVTOT_r7"] / data["r7_mean_groupby_zip5_7"]
data.head()
# Out:
#          BBLE  B  BLOCK BLDGCL TAXCLASS  LTFRONT  LTDEPTH  STORIES  \
# 0  1000010101  1      1     P7        4    500.0   1046.0     35.0
# 1  1000010201  1      1     Z9        4     27.0    355.0     35.0
# 2  1000020001  1      2     Y7        4    709.0    564.0      3.0
# 3  1000020023  1      2     T2        4    793.0    551.0      2.0
# 4  1000030001  1      3     Q1        4    323.0   1260.0      1.0
#
#        FULLVAL       AVLAND    ...       r6_byzip3 TAXCLASS_6  \
# 0   21400000.0    4225500.0    ...        0.039680          4
# 1  193800000.0   14310000.0    ...        0.134381          4
# 2  104686000.0   39008700.0    ...        1.298285          4
# 3   39200000.0   15255000.0    ...        6.502298          4
# 4  272300000.0  121050000.0    ...      952.697664          4
#
#    r6_mean_groupby_taxclass_6  r6_bytaxclass B_6  r6_mean_groupby_b_6  \
# 0                  124.797333       0.007964   1             23.71018
# 1                  124.797333       0.026970   1             23.71018
# 2                  124.797333       0.260561   1             23.71018
# 3                  124.797333       1.304988   1             23.71018
# 4                  124.797333     191.202967   1             23.71018
#
#           r6_b   ZIP5_7  r7_mean_groupby_zip5_7  r7_byzip5
# 0     0.041916  10004.0              128.530379   0.143258
# 1     0.141954  10004.0              128.530379  70.789424
# 2     1.371450  10004.0              128.530379   0.916579
# 3     6.868736  10004.0              128.530379   0.314100
# 4  1006.387148  10004.0              128.530379   2.342509
#
# [5 rows x 119 columns]

# %% [markdown]
# # var 26 (r7 group by zip3)

# %%
data_group_zip3_7 = data.groupby("ZIP3")["AVTOT_r7"].mean()
data_group_zip3_7 = pd.DataFrame({'ZIP3_7':data_group_zip3_7.index, 'r7_mean_groupby_zip3_7':data_group_zip3_7})

data = data.merge(data_group_zip3_7, on =['ZIP3'], how = 'left')

### Var22
data["r7_byzip3"] = data["AVTOT_r7"] / data["r7_mean_groupby_zip3_7"]
data.head()
# Out:
#          BBLE  B  BLOCK BLDGCL TAXCLASS  LTFRONT  LTDEPTH  STORIES  \
# 0  1000010101  1      1     P7        4    500.0   1046.0     35.0
# 1  1000010201  1      1     Z9        4     27.0    355.0     35.0
# 2  1000020001  1      2     Y7        4    709.0    564.0      3.0
# 3  1000020023  1      2     T2        4    793.0    551.0      2.0
# 4  1000030001  1      3     Q1        4    323.0   1260.0      1.0
#
#        FULLVAL       AVLAND    ...      r6_bytaxclass B_6  \
# 0   21400000.0    4225500.0    ...           0.007964   1
# 1  193800000.0   14310000.0    ...           0.026970   1
# 2  104686000.0   39008700.0    ...           0.260561   1
# 3   39200000.0   15255000.0    ...           1.304988   1
# 4  272300000.0  121050000.0    ...         191.202967   1
#
#    r6_mean_groupby_b_6         r6_b   ZIP5_7  r7_mean_groupby_zip5_7  \
# 0             23.71018     0.041916  10004.0              128.530379
# 1             23.71018     0.141954  10004.0              128.530379
# 2             23.71018     1.371450  10004.0              128.530379
# 3             23.71018     6.868736  10004.0              128.530379
# 4             23.71018  1006.387148  10004.0              128.530379
#
#    r7_byzip5  ZIP3_7  r7_mean_groupby_zip3_7  r7_byzip3
# 0   0.143258     100               99.955112   0.184213
# 1  70.789424     100               99.955112  91.026775
# 2   0.916579     100               99.955112   1.178612
# 3   0.314100     100               99.955112   0.403895
# 4   2.342509     100               99.955112   3.012188
#
# [5 rows x 122 columns]

# %% [markdown]
# # var 27 (r7 group by taxclass)

# %%
# r7 group by taxclass
data_group_taxclass_7 = data.groupby("TAXCLASS")["AVTOT_r7"].mean()
data_group_taxclass_7 = pd.DataFrame({'TAXCLASS_7':data_group_taxclass_7.index, 'r7_mean_groupby_taxclass_7':data_group_taxclass_7})

#merge
data = data.merge(data_group_taxclass_7, on =['TAXCLASS'], how = 'left')

### Var27
data["r7_bytaxclass"] = data["AVTOT_r7"] / data["r7_mean_groupby_taxclass_7"]
data.head()
# Out:
#          BBLE  B  BLOCK BLDGCL TAXCLASS  LTFRONT  LTDEPTH  STORIES  \
# 0  1000010101  1      1     P7        4    500.0   1046.0     35.0
# 1  1000010201  1      1     Z9        4     27.0    355.0     35.0
# 2  1000020001  1      2     Y7        4    709.0    564.0      3.0
# 3  1000020023  1      2     T2        4    793.0    551.0      2.0
# 4  1000030001  1      3     Q1        4    323.0   1260.0      1.0
#
#        FULLVAL       AVLAND      ...               r6_b   ZIP5_7  \
# 0   21400000.0    4225500.0      ...           0.041916  10004.0
# 1  193800000.0   14310000.0      ...           0.141954  10004.0
# 2  104686000.0   39008700.0      ...           1.371450  10004.0
# 3   39200000.0   15255000.0      ...           6.868736  10004.0
# 4  272300000.0  121050000.0      ...        1006.387148  10004.0
#
#    r7_mean_groupby_zip5_7  r7_byzip5 ZIP3_7  r7_mean_groupby_zip3_7  \
# 0              128.530379   0.143258    100               99.955112
# 1              128.530379  70.789424    100               99.955112
# 2              128.530379   0.916579    100               99.955112
# 3              128.530379   0.314100    100               99.955112
# 4              128.530379   2.342509    100               99.955112
#
#    r7_byzip3  TAXCLASS_7  r7_mean_groupby_taxclass_7  r7_bytaxclass
# 0   0.184213           4                  120.706147       0.152544
# 1  91.026775           4                  120.706147      75.378030
# 2   1.178612           4                  120.706147       0.975992
# 3   0.403895           4                  120.706147       0.334460
# 4   3.012188           4                  120.706147       2.494352
#
# [5 rows x 125 columns]

# %% [markdown]
# # var 28 (r7 group by b)

# %%
# r7 group by B
data_group_b_7 = data.groupby("B")["AVTOT_r7"].mean()
data_group_b_7 = pd.DataFrame({'B_7':data_group_b_7.index, 'r7_mean_groupby_b_7':data_group_b_7})

#merge
data = data.merge(data_group_b_7, on =['B'], how = 'left')

### Var20
data["r7_b"] = data["AVTOT_r7"] / data["r7_mean_groupby_b_7"]
data.head()
# Out:
#          BBLE  B  BLOCK BLDGCL TAXCLASS  LTFRONT  LTDEPTH  STORIES  \
# 0  1000010101  1      1     P7        4    500.0   1046.0     35.0
# 1  1000010201  1      1     Z9        4     27.0    355.0     35.0
# 2  1000020001  1      2     Y7        4    709.0    564.0      3.0
# 3  1000020023  1      2     T2        4    793.0    551.0      2.0
# 4  1000030001  1      3     Q1        4    323.0   1260.0      1.0
#
#        FULLVAL       AVLAND    ...      r7_byzip5 ZIP3_7  \
# 0   21400000.0    4225500.0    ...       0.143258    100
# 1  193800000.0   14310000.0    ...      70.789424    100
# 2  104686000.0   39008700.0    ...       0.916579    100
# 3   39200000.0   15255000.0    ...       0.314100    100
# 4  272300000.0  121050000.0    ...       2.342509    100
#
#    r7_mean_groupby_zip3_7  r7_byzip3 TAXCLASS_7  r7_mean_groupby_taxclass_7  \
# 0               99.955112   0.184213          4                  120.706147
# 1               99.955112  91.026775          4                  120.706147
# 2               99.955112   1.178612          4                  120.706147
# 3               99.955112   0.403895          4                  120.706147
# 4               99.955112   3.012188          4                  120.706147
#
#    r7_bytaxclass  B_7  r7_mean_groupby_b_7       r7_b
# 0       0.152544    1            96.767067   0.190282
# 1      75.378030    1            96.767067  94.025703
# 2       0.975992    1            96.767067   1.217442
# 3       0.334460    1            96.767067   0.417202
# 4       2.494352    1            96.767067   3.111426
#
# [5 rows x 128 columns]

# %% [markdown]
# # var 29 (r8 group by zip5)

# %%
# r8 group by zip5
data_group_zip5_8 = data.groupby("ZIP")["AVTOT_r8"].mean()
data_group_zip5_8 = pd.DataFrame({'ZIP5_8':data_group_zip5_8.index, 'r8_mean_groupby_zip5_8':data_group_zip5_8})

## create r8_mean_groupby_zip5 column
data = data.merge(data_group_zip5_8, on =['ZIP'], how = 'left')

### Var17
data["r8_byzip5"] = data["AVTOT_r8"] / data["r8_mean_groupby_zip5_8"]
data.head()
# Out:
#          BBLE  B  BLOCK BLDGCL TAXCLASS  LTFRONT  LTDEPTH  STORIES  \
# 0  1000010101  1      1     P7        4    500.0   1046.0     35.0
# 1  1000010201  1      1     Z9        4     27.0    355.0     35.0
# 2  1000020001  1      2     Y7        4    709.0    564.0      3.0
# 3  1000020023  1      2     T2        4    793.0    551.0      2.0
# 4  1000030001  1      3     Q1        4    323.0   1260.0      1.0
#
#        FULLVAL       AVLAND     ...      r7_byzip3 TAXCLASS_7  \
# 0   21400000.0    4225500.0     ...       0.184213          4
# 1  193800000.0   14310000.0     ...      91.026775          4
# 2  104686000.0   39008700.0     ...       1.178612          4
# 3   39200000.0   15255000.0     ...       0.403895          4
# 4  272300000.0  121050000.0     ...       3.012188          4
#
#    r7_mean_groupby_taxclass_7  r7_bytaxclass B_7  r7_mean_groupby_b_7  \
# 0                  120.706147       0.152544   1            96.767067
# 1                  120.706147      75.378030   1            96.767067
# 2                  120.706147       0.975992   1            96.767067
# 3                  120.706147       0.334460   1            96.767067
# 4                  120.706147       2.494352   1            96.767067
#
#         r7_b   ZIP5_8  r8_mean_groupby_zip5_8   r8_byzip5
# 0   0.190282  10004.0              171.489152    0.462274
# 1  94.025703  10004.0              171.489152    4.186385
# 2   1.217442  10004.0              171.489152    0.686972
# 3   0.417202  10004.0              171.489152    2.196299
# 4   3.111426  10004.0              171.489152  140.850580
#
# [5 rows x 131 columns]

# %% [markdown]
# # var 30 (r8 group by zip3)

# %%
data_group_zip3_8 = data.groupby("ZIP3")["AVTOT_r8"].mean()
data_group_zip3_8 = pd.DataFrame({'ZIP3_8':data_group_zip3_8.index, 'r8_mean_groupby_zip3_8':data_group_zip3_8})

data = data.merge(data_group_zip3_8, on =['ZIP3'], how = 'left')

### Var22
data["r8_byzip3"] = data["AVTOT_r8"] / data["r8_mean_groupby_zip3_8"]
data.head()

# %% [markdown]
# # var 31 (r8 group by TAXCLASS)

# %%
# r8 group by taxclass
data_group_taxclass_8 = data.groupby("TAXCLASS")["AVTOT_r8"].mean()
data_group_taxclass_8 = pd.DataFrame({'TAXCLASS_8':data_group_taxclass_8.index, 'r8_mean_groupby_taxclass_8':data_group_taxclass_8})

#merge
data = data.merge(data_group_taxclass_8, on =['TAXCLASS'], how = 'left')

### Var27
data["r8_bytaxclass"] = data["AVTOT_r8"] / data["r8_mean_groupby_taxclass_8"]
data.head()

# %% [markdown]
# # var 32 (r8 group by b)

# %%
# r8 group by B
data_group_b_8 = data.groupby("B")["AVTOT_r8"].mean()
data_group_b_8 = pd.DataFrame({'B_8':data_group_b_8.index, 'r8_mean_groupby_b_8':data_group_b_8})

#merge
data = data.merge(data_group_b_8, on =['B'], how = 'left')

### Var20
data["r8_b"] = data["AVTOT_r8"] / data["r8_mean_groupby_b_8"]
data.head()

# %% [markdown]
# # var 33 (r9 group by zip5)

# %%
# r9 group by zip5
data_group_zip5_9 = data.groupby("ZIP")["AVTOT_r9"].mean()
data_group_zip5_9 = pd.DataFrame({'ZIP5_9':data_group_zip5_9.index, 'r9_mean_groupby_zip5_9':data_group_zip5_9})

## create r9_mean_groupby_zip5 column
data = data.merge(data_group_zip5_9, on =['ZIP'], how = 'left')

### Var33
data["r9_byzip5"] = data["AVTOT_r9"] / data["r9_mean_groupby_zip5_9"]
data.head()

# %% [markdown]
# # var 34 (r9 group by zip3)

# %%
data_group_zip3_9 = data.groupby("ZIP3")["AVTOT_r9"].mean()
data_group_zip3_9 = pd.DataFrame({'ZIP3_9':data_group_zip3_9.index, 'r9_mean_groupby_zip3_9':data_group_zip3_9})

data = data.merge(data_group_zip3_9, on =['ZIP3'], how = 'left')

### Var34
data["r9_byzip3"] = data["AVTOT_r9"] / data["r9_mean_groupby_zip3_9"]
data.head()

# %% [markdown]
# # var 35 (r9 group by taxclass)

# %%
# r9 group by taxclass
data_group_taxclass_9 = data.groupby("TAXCLASS")["AVTOT_r9"].mean()
data_group_taxclass_9 = pd.DataFrame({'TAXCLASS_9':data_group_taxclass_9.index, 'r9_mean_groupby_taxclass_9':data_group_taxclass_9})

#merge
data = data.merge(data_group_taxclass_9, on =['TAXCLASS'], how = 'left')

### Var27
data["r9_bytaxclass"] = data["AVTOT_r9"] / data["r9_mean_groupby_taxclass_9"]
data.head()

# %% [markdown]
# # var 36 (r9 group by b)

# %%
# r9 group by B
data_group_b_9 = data.groupby("B")["AVTOT_r9"].mean()
data_group_b_9 = pd.DataFrame({'B_9':data_group_b_9.index, 'r9_mean_groupby_b_9':data_group_b_9})

#merge
data = data.merge(data_group_b_9, on =['B'], how = 'left')

### Var20
data["r9_b"] = data["AVTOT_r9"] / data["r9_mean_groupby_b_9"]
data.head()

# %%
list(data)
# Out:
# ['FULLVAL_r1',
#  'FULLVAL_r2',
#  'FULLVAL_r3',
#  'AVLAND_r4',
#  'AVLAND_r5',
#  'AVLAND_r6',
#  'AVTOT_r7',
#  'AVTOT_r8',
#  'AVTOT_r9',
#  'r1_byzip5',
#  'r1_byzip3',
#  'r1_bytaxclass',
#  'r1_b',
#  'r2_byzip5',
#  'r2_byzip3',
#  'r2_bytaxclass',
#  'r2_b',
#  'r3_byzip5',
#  'r3_byzip3',
#  'r3_bytaxclass',
#  'r3_b',
#  'r4_byzip5',
#  'r4_byzip3',
#  'r4_bytaxclass',
#  'r4_b',
#  'r5_byzip5',
#  'r5_byzip3',
#  'r5_bytaxclass',
#  'r5_b',
#  'r6_byzip5',
#  'r6_byzip3',
#  'r6_bytaxclass',
#  'r6_b',
#  'r7_byzip5',
#  'r7_byzip3',
#  'r7_bytaxclass',
#  'r7_b',
#  'r8_byzip5',
#  'r8_byzip3',
#  'r8_bytaxclass',
#  'r8_b',
#  'r9_byzip5',
#  'r9_byzip3',
#  'r9_bytaxclass',
#  'r9_b',
#  'r1_all',
#  'r2_all',
#  'r3_all',
#  'r4_all',
#  'r5_all',
#  'r6_all',
#  'r7_all',
#  'r8_all',
#  'r9_all']

# %%
data.drop(
    ['FULLVAL_r1',
 'FULLVAL_r2',
 'FULLVAL_r3',
 'AVLAND_r4',
 'AVLAND_r5',
 'AVLAND_r6',
 'AVTOT_r7',
 'AVTOT_r8',
 'AVTOT_r9'],axis=1, inplace=True)

# %%
data.drop(['BBLE',
 'B',
 'BLOCK',
 'BLDGCL',
 'TAXCLASS',
 'LTFRONT',
 'LTDEPTH',
 'STORIES',
 'FULLVAL',
 'AVLAND',
 'AVTOT',
 'ZIP',
 'BLDFRONT',
 'BLDDEPTH',
 'group',
 'meanFULLVAL',
 'meanAVLAND',
 'meanAVTOT',
 'medianLTFRONT',
 'medianLTDEPTH',
 'medianBLDFRONT',
 'medianBLDDEPTH',
 'lotarea',
 'bldarea',
 'bldvol',
 'ZIP5_x',
 'r1_mean_groupby_zip5',

 'ZIP3',
 'ZIP3_1_x',
 'r1_mean_groupby_zip3',

 'TAXCLASS_1_x',
 'r1_mean_groupby_taxclass',

 'B_1_x',
 'r1_mean_groupby_b',

 'ZIP5_y',
 'r2_mean_groupby_zip5_2',

 'ZIP3_1_y',
 'r2_mean_groupby_zip3_2',

 'TAXCLASS_1_y',
 'r2_mean_groupby_taxclass_2',

 'B_1_y',
 'r2_mean_groupby_b_2',

 'ZIP5',
 'r3_mean_groupby_zip5_3',

 'ZIP3_3',
 'r3_mean_groupby_zip3_3',

 'TAXCLASS_3',
 'r3_mean_groupby_taxclass_3',

 'B_3',
 'r3_mean_groupby_b_3',

 'ZIP5_4',
 'r4_mean_groupby_zip5_4',

 'ZIP3_4',
 'r4_mean_groupby_zip3_4',

 'TAXCLASS_4',
 'r4_mean_groupby_taxclass_4',

 'B_4',
 'r4_mean_groupby_b_4',

 'ZIP5_5',
 'r5_mean_groupby_zip5_5',

 'ZIP3_5_x',
 'r5_mean_groupby_zip3_5',

 'TAXCLASS_5',
 'r5_mean_groupby_taxclass_5',

 'B_5',
 'r5_mean_groupby_b_5',

 'ZIP5_6',
 'r6_mean_groupby_zip5_6',

 'ZIP3_5_y',
 'r6_mean_groupby_zip3_6',

 'TAXCLASS_6',
 'r6_mean_groupby_taxclass_6',

 'B_6',
 'r6_mean_groupby_b_6',
 
 'ZIP5_7',
 'r7_mean_groupby_zip5_7',

 'ZIP3_7',
 'r7_mean_groupby_zip3_7',

 'TAXCLASS_7',
 'r7_mean_groupby_taxclass_7',

 'B_7',
 'r7_mean_groupby_b_7',

 'ZIP5_8',
 'r8_mean_groupby_zip5_8',

 'ZIP3_8',
 'r8_mean_groupby_zip3_8',

 'TAXCLASS_8',
 'r8_mean_groupby_taxclass_8',

 'B_8',
 'r8_mean_groupby_b_8',

 'ZIP5_9',
 'r9_mean_groupby_zip5_9',

 'ZIP3_9',
 'r9_mean_groupby_zip3_9',

 'TAXCLASS_9',
 'r9_mean_groupby_taxclass_9',

 'B_9',
 'r9_mean_groupby_b_9'],axis=1, inplace=True)
data.head()
# Out:
#      FULLVAL_r1    FULLVAL_r2    FULLVAL_r3    AVLAND_r4     AVLAND_r5  \
# 0     40.917782    176.166486      5.033328     8.079350     34.784649
# 1  20219.092332   1595.376865     45.582196  1492.957746    117.801047
# 2    261.796157    261.796157     87.265386    97.551991     97.551991
# 3     89.714219    836.980890    418.490445    34.913021    325.717946
# 4    669.074647  53676.325646  53676.325646   297.434763  23861.620343
#
#       AVLAND_r6     AVTOT_r7      AVTOT_r8      AVTOT_r9  r1_byzip5  \
# 0      0.993847    18.413002     79.274919      2.264998   0.129905
# 1      3.365744  9098.591549    717.919589     20.511988  64.191313
# 2     32.517330   117.808271    117.808271     39.269424   0.831147
# 3    162.858973    40.371399    376.641401    188.320700   0.284824
# 4  23861.620343   301.083591  24154.346541  24154.346541   2.124170
#
#       ...      r7_bytaxclass       r7_b   r8_byzip5   r8_byzip3  \
# 0     ...           0.152544   0.190282    0.462274    0.510808
# 1     ...          75.378030  94.025703    4.186385    4.625914
# 2     ...           0.975992   1.217442    0.686972    0.759098
# 3     ...           0.334460   0.417202    2.196299    2.426889
# 4     ...           2.494352   3.111426  140.850580  155.638514
#
#    r8_bytaxclass        r8_b   r9_byzip5   r9_byzip3  r9_bytaxclass  \
# 0       0.205188    0.531646    0.039249    0.059239       0.013445
# 1       1.858200    4.814629    0.355443    0.536470       0.121757
# 2       0.304924    0.790065    0.680483    1.027051       0.233099
# 3       0.974865    2.525894    3.263326    4.925332       1.117851
# 4      62.518972  161.987788  418.560021  631.731769     143.377527
#
#          r9_b
# 0    0.062240
# 1    0.563649
# 2    1.079084
# 3    5.174861
# 4  663.736795
#
# [5 rows x 45 columns]

# %%
data.describe()
# Out:
#           r1_byzip5     r1_byzip3  r1_bytaxclass          r1_b     r2_byzip5  \
# count  1.070994e+06  1.070994e+06   1.070994e+06  1.070994e+06  1.070994e+06
# mean   1.000000e+00  1.000000e+00   1.000000e+00  1.000000e+00  1.000000e+00
# std    8.233529e+00  1.369310e+01   1.119993e+01  1.500539e+01  9.624314e+00
# min    1.727946e-06  4.409034e-07   6.895847e-07  7.863017e-07  1.673136e-06
# 25%    3.989361e-01  1.917273e-01   3.251270e-01  1.898008e-01  3.426325e-01
# 50%    8.753660e-01  6.742600e-01   6.430129e-01  4.472034e-01  8.565394e-01
# 75%    1.202020e+00  1.096030e+00   1.033069e+00  9.735404e-01  1.163272e+00
# max    4.615503e+03  9.833651e+03   7.589558e+03  5.302497e+03  3.977971e+03
#
#           r2_byzip3  r2_bytaxclass          r2_b     r3_byzip5     r3_byzip3  \
# count  1.070994e+06   1.070994e+06  1.070994e+06  1.070994e+06  1.070994e+06
# mean   1.000000e+00   1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# std    1.331416e+01   2.363524e+01  1.430617e+01  1.104208e+01  1.587838e+01
# min    1.215534e-06   1.230334e-06  1.251148e-06  4.463858e-07  3.116284e-07
# 25%    3.283538e-01   4.043326e-01  3.311741e-01  3.084903e-01  2.809859e-01
# 50%    8.341663e-01   7.333375e-01  8.285269e-01  8.119543e-01  8.138464e-01
# 75%    1.127465e+00   1.002475e+00  1.122793e+00  1.148081e+00  1.142607e+00
# max    6.530301e+03   1.982951e+04  6.530914e+03  5.412969e+03  8.321732e+03
#
#            ...               r9_b        r1_all        r2_all        r3_all  \
# count      ...       1.070994e+06  1.070994e+06  1.070994e+06  1.070994e+06
# mean       ...       1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# std        ...       6.122564e+01  2.269205e+01  1.503700e+01  1.595915e+01
# min        ...       8.273063e-07  1.269851e-06  1.165690e-06  1.941391e-07
# 25%        ...       2.458248e-01  2.102852e-01  3.234055e-01  2.713694e-01
# 50%        ...       4.250112e-01  4.294985e-01  8.240070e-01  8.541382e-01
# 75%        ...       5.966147e-01  6.848967e-01  1.136181e+00  1.221260e+00
# max        ...       3.705397e+04  5.742401e+03  6.883118e+03  1.049645e+04
#
#              r4_all        r5_all        r6_all        r7_all        r8_all  \
# count  1.070994e+06  1.070994e+06  1.070994e+06  1.070994e+06  1.070994e+06
# mean   1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# std    2.460323e+01  7.734346e+01  8.881629e+01  3.414578e+01  5.583302e+01
# min    6.706878e-07  1.842925e-06  2.963090e-07  2.446915e-07  5.103290e-06
# 25%    1.871219e-01  1.384350e-01  1.013312e-01  1.569348e-01  2.327587e-01
# 50%    3.694148e-01  3.537739e-01  3.561215e-01  2.551777e-01  3.588401e-01
# 75%    5.847502e-01  4.818217e-01  5.063625e-01  4.059065e-01  4.807935e-01
# max    1.498515e+04  4.407221e+04  6.488275e+04  2.688845e+04  2.904892e+04
#
#              r9_all
# count  1.070994e+06
# mean   1.000000e+00
# std    6.291688e+01
# min    9.722792e-07
# 25%    2.322636e-01
# 50%    4.172143e-01
# 75%    5.788791e-01
# max    4.257997e+04
#
# [8 rows x 45 columns]

# %%
data.shape
# Out:
# (1070994, 45)

# %%
data.head()
# Out:
#    r1_byzip5  r1_byzip3  r1_bytaxclass       r1_b   r2_byzip5  r2_byzip3  \
# 0   0.129905   0.107550       0.152607   0.110473    0.429091   0.303955
# 1  64.191313  53.144600      75.409325  54.589110    3.885882   2.752637
# 2   0.831147   0.688115       0.976398   0.706818    0.637661   0.451699
# 3   0.284824   0.235808       0.334599   0.242218    2.038646   1.444113
# 4   2.124170   1.758620       2.495387   1.806421  130.740178  92.612244
#
#    r2_bytaxclass       r2_b   r3_byzip5   r3_byzip3     ...            r9_b  \
# 0       0.216473   0.312860    0.037275    0.033819     ...        0.062240
# 1       1.960392   2.833285    0.337565    0.306268     ...        0.563649
# 2       0.321694   0.464933    0.646256    0.586339     ...        1.079084
# 3       1.028478   1.486423    3.099190    2.811852     ...        5.174861
# 4      65.957235  95.325639  397.507594  360.653117     ...      663.736795
#
#       r1_all     r2_all      r3_all      r4_all      r5_all       r6_all  \
# 0   0.115466   0.291491    0.018031    0.650247    0.818948     0.048907
# 1  57.056097   2.639763    0.163294  120.157017    2.773434     0.165627
# 2   0.738761   0.433176    0.312620    7.851231    2.296703     1.600162
# 3   0.253164   1.384896    1.499202    2.809888    7.668499     8.014211
# 4   1.888056  88.814598  192.290339   23.938302  561.783017  1174.218807
#
#        r7_all      r8_all      r9_all
# 0    0.540661    1.049730    0.073146
# 1  267.161795    9.506437    0.662419
# 2    3.459202    1.559975    1.268177
# 3    1.185425    4.987352    6.081676
# 4    8.840713  319.843317  780.046571
#
# [5 rows x 45 columns]

# %%
data.to_csv('NYP_45_var_new.csv')
